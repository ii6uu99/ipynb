# %% [markdown]
# https://www.csdn.net/
# https://www.cnblogs.com/

# %% [markdown]
# 重要，在线生成vscode 的代码段
# https://snippet-generator.app/?description=&tabtrigger=&snippet=&mode=vscode
# 源码 https://github.com/pawelgrzybek/snippet-generator
# description 说明
# tab trigger标签触发器
# (ctrl + i): ${1:example}

# %% [markdown]
# 自动化配置vscode的snippets
# https://www.jianshu.com/p/dbdb6fa3de7b
#
#
# 例子
# ${1:}
# ${2:}
#
# 菜鸟教程
# https://www.runoob.com/?s=count+python

# %% [markdown]
# 保存地址  C:\Users\Administrator\AppData\Roaming\Code\User

# %% [markdown]
# 已操作完
# https://github.com/ylcnfrht/vscode-python-snippet-pack
#
#    https://github.com/NexSabre/vscode-python-snippets
#
#
# https://github.com/cstrap/python-snippets
#
#
# 未完成
# https://github.com/taketakeyyy/my-vscode/blob/master/User/snippets/python.json

# %% [markdown]
# pynsist：制作Python程序的Windows安装包   使用NSIS制作Python程序安装包
# https://github.com/idleberg/vscode-pynsist

# %% [markdown]
# vscode-表情符号代码
# https://github.com/idleberg/vscode-emoji-code

# %% [markdown]
#   pygame.json
#   https://github.com/tushortz/vscode-Pygame-Snippets

# %% [markdown]
# Masonite
# Masonite 一个现代和以开发人员为中心的Python Web框架
# https://github.com/nioperas06/masonite-snippets-vscode
#
#
# 很多爬虫代码  https://python.ctolib.com/python/categories/python-web-crawling.html

# %% [markdown]
# OpenERP代码片段  https://github.com/TheDavidDelta/vscode-openerp-code-snippets

# %% [markdown]
# django
# https://github.com/Sid200026/Django-Snippets-VSCode

# %% [markdown]
# # 怎样打开代码片段snippet
# Ctrl+shift+p输入代码或者snippet----python.json
# 或者  文件 ---首选项---用户代码段----python.json

# %% [markdown]
# # 相关知识
#
# ${4| ,1|}  选项
# 设置多个触发词  "prefix": ["im", "imp"],
#
# prefix      :触发关键词
# body        :代码段的内容
# $1          :生成代码后光标的初始位置.
# $2          :生成代码后光标的第二个位置,按tab键可进行快速切换,还可以有$3,$4,$5.....
# ${1,字符}    :生成代码后光标的初始位置(其中1表示光标开始的序号，字符表示生成代码后光标会直接选中字符。)
# description :代码段描述,输入名字后编辑器显示的提示信息
#
# 注：
#
# 如果没有description，默认提示信息是类似上图中Print to console一样的信息（即key值）
# 代码多行语句的以 , 隔开
# 每行代码需要用引号包裹住
# 字符串间如果值里包含特殊字符需要 \ 进行转义.
#
# 换行：\r或者\n
# tab键制表符：\t
#
# 如果多个，比如${1,字符1} ${1,字符2} ${2,字符3}，光标开始会选中字符1和字符2，点击tab会切换到字符3
#
#
# scope: 域。代码片适用的「语言模式」；
# 注：可选，但只有「全局代码片」才能使用。不填代表适用于所有语言模式。

# %% [markdown]
# 如何控制光标位置（占位符）
#
# 只要掌握以下语句即可
#
# $1 $2 //光标会定位到1，按Tab会到下一个
# $0 //终止光标跳转的位置
# ${1|Boolean, Number, String|} //跳转到光标1位置时，可选{Boolean, Number, String}中的值

# %% [markdown]
# 常用的变量
# 变量	含义
# $CURRENT_YEAR	年
# $CURRENT_MONTH	月
# $CURRENT_DATE	日期
# $TM_FILENAME	当前文件名
# $TM_SELECTED_TEXT	当前选中的内容
# $CLIPBOARD	剪切板内容

# %% [markdown]
# #  变量
# 使用$name或${name:default}，您可以插入变量的值。未设置变量时，将插入其默认值或空字符串。当变量未知（即未定义其名称）时，将插入该变量的名称，并将其转换为占位符。
#
# 可以使用以下变量：
#
# TM_SELECTED_TEXT 当前选择的文本或空字符串
# TM_CURRENT_LINE 当前行的内容
# TM_CURRENT_WORD 光标下的单词内容或空字符串
# TM_LINE_INDEX 基于零索引的行号
# TM_LINE_NUMBER 基于一索引的行号
# TM_FILENAME 当前文档的文件名
# TM_FILENAME_BASE 当前文档的文件名，不带扩展名
# TM_DIRECTORY 当前文件的目录
# TM_FILEPATH 当前文档的完整文件路径
# CLIPBOARD 剪贴板中的内容
# WORKSPACE_NAME 打开的工作空间或文件夹的名称
# 要插入当前日期和时间：
#
# CURRENT_YEAR 年
# CURRENT_YEAR_SHORT 本年度的后两位数字
# CURRENT_MONTH 以两位数表示的月份（例如“ 02”）
# CURRENT_MONTH_NAME 月的全名（例如“七月”）
# CURRENT_MONTH_NAME_SHORT 月的简称（例如“ Jul”）
# CURRENT_DATE 一个月中的某天
# CURRENT_DAY_NAME 一天的名称（例如“周一”）
# CURRENT_DAY_NAME_SHORT 一天的简称（例如“ Mon”）
# CURRENT_HOUR 当前小时（24小时制）
# CURRENT_MINUTE 当前分钟
# CURRENT_SECOND 当前秒
# CURRENT_SECONDS_UNIX 自Unix时代以来的秒数
# 要插入行或块注释，请遵循当前语言：
#
# BLOCK_COMMENT_START输出示例：PHP /*或HTML<!--
# BLOCK_COMMENT_END输出示例：PHP */或HTML-->
# LINE_COMMENT 示例输出：在PHP中 //
#
#
# ------------------------------------------
# Variables：变量
#
# 使用$name或${name:default}可以插入变量的值。当变量未赋值时（如），将插入其缺省值或空字符串。 当varibale未知（即，其名称未定义）时，将插入变量的名称，并将其转换为「Placeholder」。可以使用的「Variable」如下：
#
# TM_SELECTED_TEXT：当前选定的文本或空字符串；
# 注：选定后通过在命令窗口点选「插入代码片段」插入。
# TM_CURRENT_LINE：当前行的内容；
# TM_CURRENT_WORD：光标所处单词或空字符串
# 注：所谓光标一般为文本输入处那条闪来闪去的竖线，该项可定制。单词使用 VSCode 选词（Word Wrap）器选择。你最好只用它选择英文单词，因为这个选择器明显没有针对宽字符优化过，它甚至无法识别宽字符的标点符号。
# TM_LINE_INDEX：行号（从零开始）；
# TM_LINE_NUMBER：行号（从一开始）；
# TM_FILENAME：当前文档的文件名；
# TM_FILENAME_BASE：当前文档的文件名（不含后缀名）；
# TM_DIRECTORY：当前文档所在目录；
# TM_FILEPATH：当前文档的完整文件路径；
# WORKSPACE_NAME：当前工作目录的名称（而非完整路径）；
# CLIPBOARD：当前剪贴板中内容。
# 此外，还有一些用于插入当前时间的变量，这里单独列出：
#
# CURRENT_YEAR: 当前年份；
# CURRENT_YEAR_SHORT: 当前年份的后两位；
# CURRENT_MONTH: 格式化为两位数字的当前月份，如 02；
# CURRENT_MONTH_NAME: 当前月份的全称，如 July；
# CURRENT_MONTH_NAME_SHORT: 当前月份的简称，如 Jul；
# CURRENT_DATE: 当天月份第几天；
# CURRENT_DAY_NAME: 当天周几，如 Monday；
# CURRENT_DAY_NAME_SHORT: 当天周几的简称，如 Mon；
# CURRENT_HOUR: 当前小时（24 小时制）；
# CURRENT_MINUTE: 当前分钟；
# CURRENT_SECOND: 当前秒数；
# CURRENT_SECONDS_UNIX：Unix 时间戳。
# 此外，还有一些用于插入行/块注释的变量，其将根据当前文件的语言模式自动调整：
#
# BLOCK_COMMENT_START 块注释上半段，输出示例:
# PHP: /*
# HTML: <!--
# BLOCK_COMMENT_END 块注释下半段，输出示例:
# PHP: */
# HTML: -->
# LINE_COMMENT 行注释，输出示例:
# PHP: //
# HTML: <!-- -->
# 注：这些都是变量名，不是宏，在实际使用的时要加上 $ 符。
# ————————————————
# 版权声明：本文为CSDN博主「猫科龙」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/maokelong95/article/details/54379046

# %% [markdown]
# 变量转换
# 变量转换可将变量的值格式化处理后插入预定的位置。
#
# 语法结构
# 我们可以通过 ${var_name/regular_expression/format_string/options} 插入格式化后的代码片。显然，「variable transformations」由 4 部分构成：
#
# var_name：变量名；
# regular_expression：正则表达式；
# format_string：格式串；
# options：正则表达式匹配选项。
# 其中正则表达式的写法和匹配选项部分不在本篇博文的讲解范围之内，具体内容请分别参考 javascript 有关 RegExp(pattern [, flags]) 构造函数中的 pattern 及 flags 参数项的说明2。
#
# 本文只对 format_string 部分进行详细介绍。
#
# format_string 部分
# 根据其 EBNF 范式，我们可以知道 format_string 其实是 format 或 text 的线性组合：
#
# text：也即没有任何作用的普通文本，你甚至可以使用汉字；
# format：格式串，分为 7 种：
# $sn：表示插入匹配项；
# ${sn}：同 $sn；
# ${sn:/upcase} 或 ${sn:/downcase} 或 ${sn:/capitalize}：表示将匹配项变更为「所有字母均大写/所有字母均小写/首字母大写其余小写」后，插入；
# ${sn:+if}：表示当匹配成功时，并且捕捉括号捕捉特定序号的捕捉项成功时，在捕捉项位置插入「if」所述语句；
# ${sn:?if:else}：表示当匹配成功，并且捕捉括号捕捉特定序号的捕捉项成功时，在捕捉项位置插入「if」所述语句；否则当匹配成功，但当捕捉括号捕捉特定序号的捕捉项失败时，在捕捉项位置插入「else」所述语句；
# ${sn:-else}：表示当匹配成功，但当捕捉括号捕捉特定序号的捕捉项失败时，在捕捉项位置插入「else」所述语句；
# ${sn:else}：同 ${sn:-else}。
# format 的后三条理解起来可能比较困难。这里我们以倒数第三条为例进行说明。假设我们有一个「make.c」文件，我们有这么一条 snippet: "body": "${TM_FILENAME/make.c(pp|\+\+)?/${1:?c++:clang}/}"。整个模式串匹配成功，但是捕捉括号捕捉后缀名中的 pp 或 ++ 失败，因此判断条件在捕捉括号的位置插入捕捉失败时应插入的字符串，也即「clang」。
#
# 注：
#
# 其中 sn 表示捕捉项的序号
# 其中 if 表示捕捉项捕捉成功时替换的文本
# 其中 else 表示捕捉项捕失败时替换的文本
# ————————————————
# 版权声明：本文为CSDN博主「猫科龙」的原创文章，遵循CC 4.0 BY-SA版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/maokelong95/article/details/54379046

# %% [markdown]
# # 模板
#
#  "Print to console": {
#     "prefix": "唤醒关键词",,
#     "body": [
#         "console.log('$1');",
#         "$2"
#     ],
#     "description": "说明"
# }

# %% [markdown]
# "使插入更容易的空代码段": {
# 	"prefix": "kong",
# 	"body": [
# 	"   \"使插入更容易的空代码段\": {",
# 	"        \"prefix\": \"\",",
# 	"        \"body\": [",
# 	"            \"\"",
# 	"        ],",
# 	"        \"description\": \"\"",
# 	"    }",
# 	],
# 	"description": "kong调出空的代码片段"
# }

# %% [markdown]
# "使插入更容易的空代码段": {
# 	"prefix": "kong",
# 	"body": [
#         "   \"使插入更容易的空代码段\": {",
#         "\t\t\"prefix\": \"\",",
#         "\t\t\"body\": [",
#         "\t\t\t\"\"",
#         "\t\t],",
#         "\t\t\"description\": \"\"",
#         "\t}",
# 	],
# 	"description": "kong调出空的代码片段"
# }

# %% [markdown]
# //判断可迭代对象是否有0
#
# 	"listall": {
# 		"prefix": "listall",
# 		"body": [
# 		  "all(${1:可迭代对象列表})"
#           ],
# 		"description": "列表有0判断为false"
# 	  },
#
#
# 	"tupleall": {
# 		"prefix": "tupleall",
# 		"body": [
# 		  "all(${1:可迭代对象元祖})"
#           ],
# 		"description": "tuple有0判断为false"
# 	  },
#
#
# 	"setall": {
# 		"prefix": "setall",
# 		"body": [
# 		  "all(${1:可迭代对象集合})"
#           ],
# 		"description": "set有0判断为false"
# 	  },
#
#
# 	  "dictall": {
# 		"prefix": "dictall",
# 		"body": [
# 		  "all(${1:可迭代对象字典名})"
#           ],
# 		"description": "dict有0判断为false"
# 	  },

# %% [markdown]
# ////判断可迭代对象是否有1,不是0，返回true
#
#     "listany": {
# 		"prefix": "listall",
# 		"body": [
# 		  "all(${1:可迭代对象列表,元祖，集合，字典})"
#           ],
# 		"description": "如果可迭代对象中的任何项为真，则返回 true"
# 	  },
#
#
# 	  "tupleany": {
# 		"prefix": "tupleany",
# 		"body": [
# 		  "all(${1:可迭代对象列表,元祖，集合，字典})"
#           ],
# 		"description": "如果可迭代对象中的任何项为真，则返回 true"
# 	  },
#
#
# 	  "setany": {
# 		"prefix": "setany",
# 		"body": [
# 		  "all(${1:可迭代对象列表,元祖，集合，字典})"
#           ],
# 		"description": "如果可迭代对象中的任何项为真，则返回 true"
# 	  },
#
#
# 	  "dictany": {
# 		"prefix": "dictany",
# 		"body": [
# 		  "all(${1:可迭代对象列表,元祖，集合，字典})"
#           ],
# 		"description": "如果可迭代对象中的任何项为真，则返回 true"
# 	  },

# %% [markdown]
# //编码
#
#     "bytearray": {
# 		"prefix": "bytearray",
# 		"body": "bytearray([source[, encoding[, errors]]])",
# 		"description": "返回一个新字节数组"
# 	  },
#
#      "bytes": {
#     "prefix": "bytes",
#     "body": "bytes(x, encoding, error)",
#     "description": "返回一个字节对象"
#   },

# %% [markdown]
#  "callable": {
#     "prefix": "callable",
#     "body": "callable(${1:判断对象可为函数})",
#     "description": "如果指定的对象是可调用的，则返回 true，否则为 false"
#   },

# %% [markdown]
# "chr": {
#     "prefix": "chr",
#     "body": "chr(${1:数字})",
#     "description": "返回指定 unicode 代码中的字符"
#   },

# %% [markdown]
#   "classmethod": {
#     "prefix": "classmethod",
#     "body": "classmethod(${1:函数名})",
#     "description": "将方法转换为类方法"
#   },

# %% [markdown]
# "compile": {
#     "prefix": "compile",
#     "body": "compile(source, filename, mode, flag, dont_inherit, optimize)",
#     "description": "将指定的源作为对象返回，并准备执行"
#   },

# %% [markdown]
#  "delattr": {
#     "prefix": "delattr",
#     "body": "delattr(${1:class类名对象},${2:要删除的属性})",
#     "description": "从指定的对象中删除指定的属性(属性或方法)"
#   },

# %% [markdown]
#  "dict": {
#     "prefix": "dict",
#     "body": "dict(${1:关键字参数k=v})",
#     "description": "建立一个字典"
#   },

# %% [markdown]
#  "dir": {
#     "prefix": "dir",
#     "body": "dir(${1:库名或class类名})",
#     "description": "返回指定对象的属性和方法的列表"
#   },

# %% [markdown]
#   "divmod": {
#     "prefix": "divmod",
#     "body": "divmod(${1:除数}, ${1:被除数，返回余数})",
#     "description": "当 argument1除以 argument2时返回商和余数"
#   },

# %% [markdown]
# //eval执行字符串的表达式
# "eval": {
#     "prefix": "eval",
#     "body": "eval(${1:字符串}, ${2:globals必须是字典，默认none}, ${3:locals可以是任意映射对象，默认none})",
#     "description": "执行字符串里面的表达式"
#   },
#
#   "获得当前目录文件": {
#         "prefix": ["mulu","dangqianmulu"],
#         "body": [
#           "eval(\"__import__('os').system('dir')\")",
#         ],
#         "description": "获得当前目录文件mkdir('cd /usr/local ;创建文件') eval('os.system("rm-rf"))"
#         },

# %% [markdown]
# "exec": {
#     "prefix": "exec",
#     "body": "exec(${1:单引号-多引号--字符串代码}, globals, locals)",
#     "description": "执行字符串里面的代码，单引号，多引号的代码)
# "
#   },

# %% [markdown]
#  "filter": {
#     "prefix": "filter",
#     "body": "filter(${1:过滤条件的函数}, ${2:可迭代对象列表,元祖，集合，字典})",
#     "description": "使用过滤器函数排除可迭代对象中的项"
#   },

# %% [markdown]
# "format": {
#     "prefix": "format",
#     "body": "format(${1:数值}, ${2:format})",
#     "description": "格式化指定的值"
#   },

# %% [markdown]
#  "frozenset": {
#     "prefix": "frozenset",
#     "body": "frozenset(${1:要冻结的可迭代对象列表,元祖，集合，字典})",
#     "description": "返回一个冻结的集合，不能再添加或删除任何集合里的元素"
#   },

# %% [markdown]
#  "getattr": {
#     "prefix": "getattr",
#     "body": "getattr(${1:元素对象，class类名}, ${2:字符串，类属性},${3:在2里找没有则返回这个默认值})",
#     "description": "返回指定属性(属性或方法)的值"
#   },

# %% [markdown]
#   "globals": {
#     "prefix": "globals",
#     "body": "globals(${1:要返回全部全局变量的对象名})",
#     "description": "返回一个全局变量的字典，包括所有导入的变量，或切割x['__file__']) "
#   },

# %% [markdown]
#  "hasattr": {
#     "prefix": "hasattr",
#     "body": "hasattr(${1:元素对象，class类名},${2:字符串，属性名})",
#     "description": "判断对象是否包含对应的属性，返回true和flase"
#   },

# %% [markdown]
# "hash": {
#     "prefix": "hash",
#     "body": "hash(${1:字符串或数值})",
#     "description": "获取取一个对象（字符串或者数值等）的哈希值"
#   },

# %% [markdown]
# //数字类型.json
#
# //整数int
# "int": {
#     "prefix": "int",
#     "body": "int(${1:字符串或数字},${2:进制数，默认10进制})",
#     "description": "将一个字符串或数字转换为整型"
#   },
#
#   "isinstance": {
#     "prefix": "isinstance",
#     "body": "isinstance(${1:对象}, ${2:可以是直接或间接类名、基本类型int，str，list或者由它们组成的元组})",
#     "description": "判断一个对象是否是一个已知的类型"
#   },
#
#   //bool
#
#     "bool": {
# 		"prefix": "bool",
# 		"body": [
# 			"bool(${1:数字})"
# 		],
# 		"description": "返回对象的布尔值"
#
#
#   //浮点数，小数
#    "float": {
#     "prefix": "float",
#     "body": "float(${1:数值})",
#     "description": "返回一个浮点数"
#   },
#
#   //浮点数x的四舍五入值
#    "round": {
#     "prefix": ["round","fudianshu","sishewuru"],
#     "body": "round(${1:数值},${2:小数点位数})",
#     "description": "返回浮点数x的四舍五入值"
#   },
#
#   //正负无穷大https://blog.csdn.net/shennongzhaizhu/article/details/51997887
#    "Large Number": {
#         "prefix": "large_number",
#         "body": [
#             "float(\"inf\")"
#         ],
#         "description": "正无穷"
#     },
#     "Small Number": {
#         "prefix": "small_number",
#         "body": [
#             "float(\"-inf\")"
#         ],
#         "description": "负无穷"
#     },
#
#   //复数complex, 如 1 + 2j、 1.1 + 2.2j
#    "complex": {
#     "prefix": "complex",
#     "body": "complex(real, imaginary)",
#     "description": "返回一个复数，(real + imag * 1j) ，其中 imag 默认为0"
#   },
#
#   //随机数
#
#
#     "randrange": {
#         "prefix": "random.randrange",
#         "body": [
#             "random.randrange(${1:stop})"
#         ],
#         "description": "从开始到结束获取随机数"
#     },
#
#
#     "randint": {
#         "prefix": ["random.randint","suijizhengshu","suijiint"],
#         "body": [
#             "random.randint(${1:start},${2:stop})"
#         ],
#         "description": "从开始到结束获取随机的整数"
#     },
#
#
#     "random": {
#         "prefix": "random.random",
#         "body": [
#             "random.random()"
#         ],
#         "description": "创建一个从0到1的随机数"
#     },

# %% [markdown]
#  "id": {
#     "prefix": "id",
#     "body": "id(${1:对象名，如class})",
#     "description": "获取对象的内存地址"
#   },

# %% [markdown]
# "iter": {
#     "prefix": "iter",
#     "body": "iter(${1:支持迭代的集合对象如列表}, ${2:可省略可调用的函数})",
#     "description": "生成迭代器"
#   },
#
#
#   "next": {
#     "prefix": "next",
#     "body": "next(${1:可迭代对象列表,元祖，集合，字典}, ${2:迭代完返回的默认值})",
#     "description": "返回可迭代对象列表,元祖，集合，字典的下一个项目，缺第二参数try--except StopIteration:break"
#   },

# %% [markdown]
# "len": {
#     "prefix": "len",
#     "body": "len(${1:字符、列表、元组等})",
#     "description": "返回对象（字符、列表、元组等）长度或项目个数"
#   },

# %% [markdown]
# "locals": {
#     "prefix": "locals",
#     "body": "locals()",
#     "description": "返回当前位置的全部局部变量的字典，对于函数, 方法, lambda 函式, 类, 以及实现了 __call__ 方法的类实例, 它都返回 True"
#   },

# %% [markdown]
#  "max": {
#     "prefix": "max",
#     "body": "max(${1:可迭代对象列表,元祖，集合，字典})",
#     "description": "返回给定参数的最大值，参数可以为序列"
#   },

# %% [markdown]
#  "memoryview": {
#     "prefix": "memoryview",
#     "body": "memoryview(${1:对象})",
#     "description": "在内存缓冲区查看对象，返回元组列表，可索引访问"
#   },

# %% [markdown]
#  "min": {
#     "prefix": "min",
#     "body": "min((${1:可迭代对象列表,元祖，集合，字典})",
#     "description": "返回给定参数的最小值，参数可以为序列"
#   },

# %% [markdown]
# "object": {
#     "prefix": "object",
#     "body": "object()",
#     "description": "返回一个新对象"
#   },

# %% [markdown]
# "open": {
#     "prefix": "open",
#     "body": "open(${1:文件路径},${2:打开模式},buffering=-1${3:设置缓冲},encoding=None${4:一般使用utf8}, errors=None${5:报错级别}, newline=None${6:区分换行符}, closefd=True${7:传入的file参数类型}, opener=None${8:})",
#     "description": "打开一个文件，并返回文件对象，在对文件进行处理过程都需要使用到这个函数，如果该文件无法被打开，会抛出 OSError"
#   },

# %% [markdown]
# "ord": {
#     "prefix": "ord",
#     "body": "ord(${1:英文字符的十进制})",
#     "description": "返回值是对应的十进制整数"
#   },

# %% [markdown]
#  "pow": {
#     "prefix": "pow",
#     "body": "pow(x, y)",
#     "description": "import math，返回 xy（x的y次方） 的值"
#   },

# %% [markdown]
# //https://www.runoob.com/python/python-func-property.html
# "property": {
#     "prefix": "property",
#     "body": "property(fget=${1:获取属性值的函数None}, fset=${2:设置属性值的函数None}, fdel= ${3:删除属性值函数None}, doc=${4:属性描述信息None})",
#     "description": "在新式类中返回属性值"
#   },

# %% [markdown]
#  "repr": {
#     "prefix": ["repr","zhuanstr"],
#     "body": "repr(${1:要转换为字符串的对象})",
#     "description": "将对象如字典转化为字符串"
#   },

# %% [markdown]
#  "reversed": {
#     "prefix": "reversed",
#     "body": "reversed(${1:要转换的序列，可以是 tuple, string, list 或 range})",
#     "description": "返回一个反转的迭代器"
#   },

# %% [markdown]
#  "set": {
#     "prefix": "set",
#     "body": "set(iterable)",
#     "description": "创建一个无序不重复元素集，可进行关系测试，删除重复数据，&交|并-差"
#   },

# %% [markdown]
# "setattr": {
#     "prefix": "setattr",
#     "body": "setattr(${1:类名}, ${2:字符串，类属性}, ${2:属性值})",
#     "description": "用于设置属性值，该属性不一定是存在的print(对象.对象属性)，返回属性值"
#   },

# %% [markdown]
# "slice": {
#     "prefix": "slice",
#     "body": "slice(${1:起始位置}, ${2:结束位置},${3:步进})",
#     "description": "对象切片如range元祖列表，主要用在切片操作函数里的参数传递，x = slice(参数) print(a[x])"
#   },

# %% [markdown]
#  "sorted": {
#     "prefix": "sorted",
#     "body": "sorted(${1:可迭代对象}, key=${2:指定排序的元素}, reverse=${3: 默认False为升序，True为降序})",
#     "description": "sort是对已经存在的列表进行操作，无返回值，sorted返回的是一个新的列表"
#   },

# %% [markdown]
# "str": {
#     "prefix": "str",
#     "body": "str(${1:如数字字典}, encoding=${2:编码方式}e, errors=${3:None})",
#     "description": "返回一个对象的string格式"
#   },

# %% [markdown]
# "sum": {
#     "prefix": "sum",
#     "body": "sum(${1:可迭代对象，如：列表、元组、集合}, ${2:指定相加的参数，默认为0})",
#     "description": "求和计算"
#   },

# %% [markdown]
# //https://www.runoob.com/w3cnote/python-super-detail-intro.html
# "super": {
#     "prefix": "super",
#     "body": "super(type[, object-or-type])",
#     "description": "返回一个代理对象，该对象将方法调用委托给类型为的父类或兄弟类"
#   },

# %% [markdown]
# "tuple": {
#     "prefix": "tuple",
#     "body": "tuple(${1:字符串，列表，字典，集合转化为元组})",
#     "description": "将可迭代系列（如列表）转换为元组"
#   },

# %% [markdown]
# //https://www.runoob.com/python/python-func-type.html
# "type": {
#     "prefix": "type",
#     "body": "type(object, bases, dict)",
#     "description": "一个参数返回对象类型, 三个参数，返回新的类型对象"
#   },

# %% [markdown]
# "unichr": {
#     "prefix": "unichr",
#     "body": "unichr(${1:10进制或16进制的数字})",
#     "description": "返回unicode 的字符"
#   },

# %% [markdown]
# "vars": {
#     "prefix": "vars",
#     "body": "vars(${1:class类名})",
#     "description": "返回一个字典，存储属性和属性值，print(vars(类名))"
#   },

# %% [markdown]
#  "zip": {
#     "prefix": "zip",
#     "body": "zip(${1:iterator1}, ${1:iterqator2})",
#     "description": "将可迭代的对象作为参数，将对象中对应的元素打包成一个个元组，然后返回由这些元组组成的列表"
#   },

# %% [markdown]
#  "range": {
#     "prefix": "range",
#     "body": "range(${1:开始}, ${2:结束},${3:步进})",
#     "description": "返回的是可迭代对象而不是列表类型，可以利用 list 函数返回列表并打印"
#   },
#
#
# "for": {
#     "prefix": "for",
#     "body": [
#       "for item in ${1:range，字符串，列表，元祖，集合}:",
#       "${2:执行语句}"
#     ],
#     "description": "for语句"
#   },

# %% [markdown]
# //while语句
#
#   "while": {
#     "prefix": "while",
#     "body": [
#       "while expression:",
#       "  pass"
#     ],
#     "description": "while语句"
#   },
#
#   "while_else": {
#     "prefix": "while_else",
#     "body": [
#       "while expression:",
#       "  pass",
#       "else:",
#       "  pass"
#     ],
#     "description": "while语句"
#   },

# %% [markdown]
# "while=>": {
#     "prefix": "while=>",
#     "body": [
#       "i = 1",
#       "while i < 6:",
#       "  print(i)",
#       "  i += 1"
#     ],
#     "description": "while Statements"
#   },
#   "while=>break_statement": {
#     "prefix": "while=>break_statement",
#     "body": [
#       "i = 1",
#       "while i < 6:",
#       " print(i)",
#       "  if i == 3:",
#       "    break",
#       "  i += 1"
#     ],
#     "description": "while Statements"
#   },
#   "while=>continue_statement": {
#     "prefix": "while=>continue_statement",
#     "body": [
#       "i = 1",
#       "while i < 6:",
#       "  i += 1",
#       "  print(i)",
#       "  if i == 3:",
#       "    continue",
#       "  print(i)"
#     ],
#     "description": "while Statements"
#   },

# %% [markdown]
# "capitalize": {
#     "prefix": ".capitalize",
#     "body": ".capitalize()",
#     "description": "首个单词的第一个字母变成大写,其他字母变小写"
#   },

# %% [markdown]
# "casefold": {
#     "prefix": ".casefold",
#     "body": ".casefold()",
#     "description": "将字符串转换为小写"
#   },

# %% [markdown]
#  "center": {
#     "prefix": ".center",
#     "body": "${1:字符串名}.center(${2:字符串的总长度},'${3:填充字符}')",
#     "description": "返回一个原字符串居中,并使用空格填充至定义长度的新字符串"
#   },

# %% [markdown]
#  "string.count": {
#     "prefix": ".count",
#     "body": ".count(${1:字符串}${2:开始索引}${3:结束索引})",
#     "description": "统计字符串里某个字符出现的次数。可选参数为在字符串搜索的开始与结束位置"
#   },

# %% [markdown]
# "string.encode=>": {
#     "prefix": "string.encode=>",
#     "body": [
#       "${1:字符串名}.encode(encoding='UTF-8',errors='strict')",
#     ],
#     "description": "以 encoding 指定的编码格式编码字符串。errors参数可以指定不同的错误处理方案"
#   },

# %% [markdown]
#  "endswith": {
#     "prefix": ".endswith",
#     "body": ".endswith(${1:字符串或者是一个元素作为结尾后缀},${2:开始索引},${3:结束索引})",
#     "description": "判断字符串是否以指定后缀结尾，如果以指定后缀结尾返回True，否则返回False"
#   },

# %% [markdown]
# "expandtabs": {
#     "prefix": ".expandtabs",
#     "body": "${1:字符串名}.expandtabs(tabsize=${2:默认8个空格})",
#     "description": "把字符串中的 tab 符号('\t')转为多少个空格，默认8"
#   },

# %% [markdown]
# "find": {
#     "prefix": ".find",
#     "body": "${1:父字符串名}.find(${2:子字符串})",
#     "description": "子字符串返回开始的索引值，否则返回-1,后两个参数beg=0, end=len(父字符串的长度)"
#   },

# %% [markdown]
# "format": {
#     "prefix": ".format",
#     "body": "${1:字符串{参数名或索引}}.format(${2:参数名=值})",
#     "description": "往字符串内传入多个变量参数"
#   },

# %% [markdown]
# "format_map": {
#     "prefix": ".format_map",
#     "body": "${1:字符串{字典k}}.format_map(${2:字典名})",
#     "description": "将字典的v值传给k"
#   },

# %% [markdown]
#  "index": {
#     "prefix": ".index",
#     "body": "${1:父字符串名}.index(${2:子字符串},beg=0, end=len(${3:父字符串})",
#     "description": "如果包含子字符串返回开始的索引值，否则抛出异常"
#   },

# %% [markdown]
# "isalnum": {
#     "prefix": ".isalnum",
#     "body": "${1:字符串名}.isalnum()",
#     "description": "如果 string 至少有一个字符并且所有字符都是字母或数字则返回 True,否则返回 False"
#   },

# %% [markdown]
# "isalpha": {
#     "prefix": ".isalpha",
#     "body": "${1:字符串名}.isalpha()",
#     "description": "有字母和中文True，有字母没中文False"
#   },

# %% [markdown]
#  "isdecimal": {
#     "prefix": ".isdecimal",
#     "body": "${1:字符串名}.isdecimal()",
#     "description": "检查字符串是否只包含十进制字符。这种方法只存在于unicode对象，全是10进制true"
#   },

# %% [markdown]
# "isdigit": {
#     "prefix": ".isdigit",
#     "body": "${1:字符串名}.isdigit()",
#     "description": "检测字符串只有数字ture，否则返回 False"
#   },

# %% [markdown]
#  "isidentifier": {
#     "prefix": ".isidentifier",
#     "body": "${1:字符串名}.isidentifier()",
#     "description": "字符串是标识符True，变量名以数字开头或者有空格返回flase"
#   },

# %% [markdown]
# "islower": {
#     "prefix": ".islower",
#     "body": "${1:字符串名}.islower()",
#     "description": "检测字符串全是小写字母ture，只要有一个是大写字母flase"
#   }

# %% [markdown]
# "isnumeric": {
#     "prefix": ".isnumeric",
#     "body": "${1:字符串名}.isnumeric()",
#     "description": "判断字符串中只包含数字字符，数字可以是： Unicode 数字，全角数字（双字节），罗马数字，汉字数字，则返回 True，有字母 False，"
#   },

# %% [markdown]
#  "isprintable": {
#     "prefix": ".isprintable",
#     "body": "${1:字符串名}.isprintable()",
#     "description": "如果字符串中的所有字符都可打印，则返回True，字符串有转义符如\n返回flase"
#   },

# %% [markdown]
# "isspace": {
#     "prefix": ".isspace",
#     "body": "${1:字符串名}.isspace()",
#     "description": "字符串中只存在空格，则返回 True，否则返回 False"
#   },

# %% [markdown]
# "istitle": {
#     "prefix": ".istitle",
#     "body": ".istitle()",
#     "description": "如果字符串中所有的单词拼写首字母是否为大写，且其他字母为小写则返回 True，否则返回 False"
#   },

# %% [markdown]
# "isupper": {
#     "prefix": ".isupper",
#     "body": "${1:字符串名}.isupper()",
#     "description": "字符串中所有的字母全是大写ture"
#   },

# %% [markdown]
# "join": {
#     "prefix": ".join",
#     "body": "${1:连接符如-空#字符串}.join(${2:字符串元素元祖字典})",
#     "description": "将iterable的元素连接到字符串的末尾"
#   },

# %% [markdown]
# "ljust": {
#     "prefix": ".ljust",
#     "body": "${1:字符串名}.ljust(${1:指定字符串长度}，${2:,填充字符默认为空格})",
#     "description": "返回一个原字符串左对齐,并使用空格填充至指定长度的新字符串。如果指定的长度小于原字符串的长度则返回原字符串"
#   },

# %% [markdown]
# "lower": {
#     "prefix": ".lower",
#     "body": "${1:字符串名}.lower()",
#     "description": "转换字符串中所有大写字符为小写"
#   },

# %% [markdown]
# "lstrip": {
#     "prefix": ".lstrip",
#     "body": ".lstrip()",
#     "description": "删除字符串左边的空格或lstrip'删除指定字符如字母逗号点')"
#   },
#
#   "rstrip": {
#     "prefix": ".rstrip",
#     "body": ".rstrip()",
#     "description": "删除字符串右边的空格或rstrip'删除指定字符如字母逗号点')"
#   },

# %% [markdown]
#  //字符串的映射替换
#
#  "maketrans": {
#     "prefix": ".maketrans",
#     "body": "${1:父类字符串}.maketrans(${2:父类中k字符串},${3:v字符串})",
#     "description": ""以字典的方式来替换父类字符串的某些元素"
#   },
#
#
#    "translate": {
#     "prefix": ".translate",
#     "body": ".translate(${1:翻译表字典，可以通过 maketrans() 制作字典},${2:字符串中要过滤的字符列表})",
#     "description": "根据参数table给出的表(包含 256 个字符)转换字符串的字符,要过滤掉的字符放到 deletechars 参数中,表指定{97: None, 98: None, 99: 105}"
#   },

# %% [markdown]
# "partition": {
#     "prefix": ".partition",
#     "body": "${1:字符串名}.partition(${2:分隔符可以是单词})",
#     "description": "根据指定的分隔符将字符串进行分割，返回字符串的元祖"
#   },
#
#   "rpartition": {
#     "prefix": ".rpartition",
#     "body": ".rpartition()",
#     "description": "右边开始搜索分割符，返回一个3元的元组，第一个为分隔符左边的子串，第二个为分隔符本身，第三个为分隔符右边的子串"
#   },

# %% [markdown]
# "replace": {
#     "prefix": ".replace",
#     "body": ".replace(${1:老字符串}, ${2:新字符串}${3:,最大替换次数})",
#     "description": "把字符串中的 old（旧字符串） 替换成 new(新字符串)，如果指定第三个参数max，则替换不超过 max 次"
#   },

# %% [markdown]
# "rfind": {
#     "prefix": ".rfind",
#     "body": ".rfind(查找的字符串,beg=0 end=len(string))",
#     "description": "返回字符串最后一次出现的索引(从右向左查询)，如果没有匹配项则返回-1"
#   },

# %% [markdown]
# "rindex": {
#     "prefix": ".rindex",
#     "body": "${1:父字符串}.rindex(${2:子字符串})",
#     "description": "返回子字符串 str 在字符串中最后出现的索引，如果没有匹配的字符串会报异常ValueError: substring not found"
#   },

# %% [markdown]
# "rsplit": {
#     "prefix": ".rsplit",
#     "body": "${1:字符串}.rsplit(${2:‘分隔符如逗号’})",
#     "description": "返回字符串的右修剪版本，返回一个列表"
#   },
#
#   "split": {
#     "prefix": ".split",
#     "body": ".split(${1:分隔符，默认为所有的空字符，包括空格、逗号、换行(\n)、制表符(\t)等},${2:分割次数。默认为 -1, 即分隔所有})",
#     "description": "通过指定分隔符对字符串进行切片，返回一个列表"
#   },

# %% [markdown]
# "splitlines": {
#     "prefix": ".splitlines",
#     "body": ".splitlines()",
#     "description": "按照行('\r', '\r\n', \n')分隔，返回一个包含各行作为元素的列表，(True)保留换行符,默认为Flase不保留换行符"
#   },

# %% [markdown]
# "startswith": {
#     "prefix": ".startswith",
#     "body": "${1:父字符串}.startswith(${2:子字符串}${3:开始索引，结束索引})",
#     "description": "检查字符串是否是以指定子字符串开头，如果是则返回 True，否则返回 False。如果参数 beg 和 end 指定值，则在指定范围内检查。"
#   },

# %% [markdown]
# "swapcase": {
#     "prefix": ".swapcase",
#     "body": ".swapcase()",
#     "description": "对字符串的大小写字母互相转换"
#   },

# %% [markdown]
#  },
#   "title": {
#     "prefix": ".title",
#     "body": ".title()",
#     "description": "返回标题化的字符串,就是说所有单词的首字母都转化为大写，b2b2b2有数字隔开的也要变大写"
#   },

# %% [markdown]
#   "upper": {
#     "prefix": ".upper",
#     "body": ".upper()",
#     "description": "将字符串中的小写字母转为大写字母"
#   },

# %% [markdown]
# "zfill": {
#     "prefix": ".zfill",
#     "body": "${1:}.zfill(${2:指定字符串的长度。原字符串右对齐，前面填充0})",
#     "description": "指定字符串的长度，原字符串右对齐，缺的填充0"
#   },

# %% [markdown]
# "append": {
#     "prefix": ".append",
#     "body": "${1:列表名}.append(${2:添加到列表末尾的对象，单值或列表})",
#     "description": "在列表末尾添加新的对象，该方法无返回值，但是会修改原来的列表"
#   },

# %% [markdown]
# "列表清空": {
#     "prefix": ".clear",
#     "body": "${1:列表名}.clear()",
#     "description": "清空列表"
#   },
#
#   "字典清空": {
#     "prefix": ".clear",
#     "body": "${1:字典名}.clear()",
#     "description": "清空列表"
#   },
#
#
#   "集合清空": {
#     "prefix": ".clear",
#     "body": ".clear()",
#     "description": "清空集合"
#   },

# %% [markdown]
#   "列表复制": {
#     "prefix": ".copy",
#     "body": "${1:列表名}.copy()",
#     "description": "复制列表，类似于 a[:]，返回复制后的新列表"
#   },
#
#   "字典复制": {
#     "prefix": ".copy",
#     "body": "${1:列表名}.copy()",
#     "description": "复制字典，类似于 a[:]，返回复制后的新字典"
#   },
#
#
#   "集合复制": {
#     "prefix": ".copy",
#     "body": ".copy()",
#     "description": "复制集合"
#   },

# %% [markdown]
# "列表count": {
#     "prefix": ".count",
#     "body": "${1:列表}.count(${2:列表中统计的元素})",
#     "description": "返回元素在列表中出现的次数"
#   },
#
#   "元祖count": {
#     "prefix": ".count",
#     "body": "${1:元祖}.count(${2:元祖中统计的元素})",
#     "description": "返回元素在列表中出现的次数"
#   },

# %% [markdown]
# "extend": {
#     "prefix": ".extend",
#     "body": "${1:}.extend(${2:元素列表，可以是列表、元组、集合、字典，若为字典,则仅会将键(key)作为元素依次添加至原列表的末尾})",
#     "description": "用于在列表末尾一次性追加另一个序列中的多个值（用新列表扩展原来的列表），修改原表"
#   },

# %% [markdown]
#   "列表index": {
#     "prefix": ".index",
#     "body": "${1:列表}.index(${1:查找的对象，可加索引开始结束})",
#     "description": "在列表中找出某个值第一个匹配项的索引位置，如果没有找到对象则抛出异常"
#   },
#
#
#   "元祖index": {
#     "prefix": ".index",
#     "body": "${1:元祖}.index(${1:查找的对象，可加索引开始结束})",
#     "description": "在元祖中找出某个值第一个匹配项的索引位置，如果没有找到对象则抛出异常"
#   },

# %% [markdown]
#   "insert": {
#     "prefix": ".insert",
#     "body": "${1:列表名}.insert(${2:在列表插入的索引},${3:要插入列表中的对象})",
#     "description": "将指定对象插入列表的指定位置,修改原表"
#   },

# %% [markdown]
# "列表pop": {
#     "prefix": ".pop",
#     "body": "${1:列表名}.pop( ${2:可选参数，要移除列表元素的索引值，不能超过列表总长度，默认为 index=-1，删除最后一个列表值})",
#     "description": "移除列表中的一个元素（默认最后一个元素），并且返回该元素的值"
#   },
#
#   "字典pop": {
#     "prefix": ".pop",
#     "body": "${1:字典名}.pop(${2:要删除的k键}${3:如果没有 key，返回 default 值})",
#     "description": "删除字典给定键 key 及对应的值，返回值为被删除的值。key 值必须给出。 否则，返回 default 值"
#   },
#
#   "集合pop": {
#     "prefix": ".pop",
#     "body": "${1:集合名}.pop()",
#     "description": "随机移除一个元素，并返回移除的元素"
#   },

# %% [markdown]
#   "列表remove": {
#     "prefix": ".remove",
#     "body": "${1:列表中要移除的对象}.remove(${2:})",
#     "description": "移除列表中某个值的第一个匹配项"
#   },
#
#   "集合remove": {
#     "prefix": ".remove",
#     "body": "${1:集合名}.remove(${2:要移除的元素})",
#     "description": "移除集合中的指定元素，不同于 discard() 方法，因为 remove() 方法在移除一个不存在的元素时会发生错误，而 discard() 方法不会"
#   },

# %% [markdown]
#   "reverse": {
#     "prefix": ".reverse",
#     "body": "${1:列表名}.reverse()",
#     "description": "反向排序列表的元素"
#   },

# %% [markdown]
# "sort": {
#     "prefix": ".sort",
#     "body": "${1:}.sort(cmp=${2:排序的方法None}, key=${3:可以是外部函数名或lambda e:len(e)或None}, reverse=${4:False升序true降序})",
#     "description": "对原列表进行排序，如果指定参数，则使用比较函数指定的比较函数"
#   },

# %% [markdown]
# "comprehensions": {
#     "prefix": "comp=>",
#     "body": "[${1:对item处理后返回值} for item in ${2:列表名} if ${3:条件}]",
#     "description": "列表推导式"
#   },

# %% [markdown]
# //字典
#
#
#     "字典建立-分配k键": {
#     "prefix": ".fromkeys",
#     "body": "dict.fromkeys(${1:元祖或列表作为k键}, ${2:v值默认none或指定})",
#     "description": "创建一个新字典，以序列中元素做字典的k键，字典所有键对应的初始值为none"
#   },
#
#
#     "enumerate": {
#     "prefix": "enumerate",
#     "body": "enumerate(${1:可迭代对象列表,元祖，集合，字典}, ${2:开始的索引})",
#     "description": "迭代对象返回索引和值"
#   },
#
#   "字典获取k键的v值": {
#     "prefix": ".get",
#     "body": ".get(${1:字典中要查找的键},${2:如果指定键的值不存在时，返回该默认值值})",
#     "description": "返回指定键的值，如果值不在字典中返回默认值"
#   },
#
#
#
#
#     “For in-迭代索引和值”: {
#     “prefix”: [“for/enum”,"forivin"],
#     “body”: [
#     “for ${1:index}, ${2:item} in enumerate(${3:iterable}):”,
#     "\t${4:pass}"
#     ],
#     “description”: “迭代索引和值for-iv-in 列表”
#     }
#
#
#     "items": {
#     "prefix": ".items",
#     "body": "${1:字典名}.items()",
#     "description": "返回kv元祖的列表，for k,v in 字典.items（）---[].append(k)"
#   },
#
#       "字典k键获取": {
#     "prefix": ".keys",
#     "body": "${1:字典名}.keys()",
#     "description": "返回包含k键的可迭代对象，可以使用 list() 来转换为列表"
#   },
#
#     "popitem": {
#     "prefix": ".popitem",
#     "body": ".popitem()",
#     "description": "删除字典中的最后一对键和值，返回元祖(k,v)，如果字典已经为空，却调用了此方法，就报出 KeyError 异常"
#   },
#
#      "setdefault": {
#     "prefix": ".setdefault",
#     "body": "${1:}.setdefault(${2:查找的键值},${3:键不存在时，设置的默认键值None})",
#     "description": "和 get()方法 类似, 如果键不在字典中，返回设置的默认值"
#   },
#
#     "update": {
#     "prefix": ".update",
#     "body": "${1:字典1}.update(${2:字典2})",
#     "description": "把字典2的参数 k键v值更新到字典字典1里，没有kv则添加进去"
#   },
#
#   "values": {
#     "prefix": ".values",
#     "body": "${1:字典名}.values()",
#     "description": "返回一个v值得迭代器，可以使用 list() 来转换为列表，列表为字典中的所有值"
#   },

# %% [markdown]
# // 集合.json
#
#
#   "add": {
#     "prefix": ".add",
#     "body": "${1:集合名}.add(${2:必需，要添加的元素})",
#     "description": "给集合添加元素，如果添加的元素在集合中已存在，则不执行任何操作"
#   },

# %% [markdown]
#   "difference": {
#     "prefix": ".difference",
#     "body": "${1:集合1}.difference(${2:集合2，计算两集合的差集})",
#     "description": "返回集合的差集，即返回的集合元素包含在第一个集合中，但不包含在第二个集合(方法的参数)中"
#   },

# %% [markdown]
#   "difference_update": {
#     "prefix": ".difference_update",
#     "body": "${1:集合1}.difference_update(${2:集合2，计算两集合的差集)",
#     "description": "移除两个集合中都存在的元素，计算两集合的差集"
#   },

# %% [markdown]
# "discard": {
#     "prefix": ".discard",
#     "body": "${1:集合}.discard${2:必需，要移除的元素})",
#     "description": "移除指定的集合元素，元素不存在不报错"
#   },

# %% [markdown]
# "intersection": {
#     "prefix": ".intersection",
#     "body": "${1:集合名}.intersection(一个或多个集合逗号隔开，进行交集)",
#     "description": "返回两个或更多集合中都包含的元素，即交集，返回一个新的集合"
#   },

# %% [markdown]
#   "intersection_update": {
#     "prefix": ".intersection_update",
#     "body": "${1:集合名}.intersection_update(${2:进行交集})",
#     "description": "获取两个或更多集合中都重叠的元素，即计算交集，在原始的集合上移除不重叠的元素"
#   },

# %% [markdown]
#   "isdisjoint": {
#     "prefix": ".isdisjoint",
#     "body": "${1:集合名}.isdisjoint(${2:必需，要比较的集合})",
#     "description": "判断两个集合是否包含相同的元素，如果没有返回 True，否则返回 False"
#   },

# %% [markdown]
#  "issubset": {
#     "prefix": ".issubset",
#     "body": "${1:子集}.issubset(${2:父集})",
#     "description": "判断子集的所有元素是否都包含在父集中，如果是则返回 True，否则返回 False"
#   },

# %% [markdown]
# "issuperset": {
#     "prefix": ".issuperset",
#     "body": "${1:父集}.issuperset(${2:子集})",
#     "description": "判断指定集合的所有元素是否都包含在原始的集合中，如果是则返回 True，否则返回 False"
#   },

# %% [markdown]
#   "symmetric_difference_update": {
#     "prefix": ".symmetric_difference_update",
#     "body": "${1:集合a名}.symmetric_difference_update(${2:要检测的集合b})",
#     "description": "移除ab集合相同的元素，并将ab不同的元素合并"
#   },

# %% [markdown]
#   "union": {
#     "prefix": ".union",
#     "body": "${1:集合a名}.union(${2:集合b})",
#     "description": "合并两个集合，重复元素只会出现一次"
#   },

# %% [markdown]
# "update": {
#     "prefix": ".update",
#     "body": "x.update(y)",
#     "description": "修改当前集合，可以添加新的元素或集合到当前集合中，重复元素只会出现一次"
#   },

# %% [markdown]
#   "class": {
#     "prefix": "class=>",
#     "body": [
#       "class ${1:类名}:",
#       "  pass"
#     ],
#     "description": "类定义"
#   },
#
#
#     "__init__": {
#     "prefix": "__init__=>",
#     "body": [
#       "def __init__(self, name, age):",
#       "  self.name = name",
#       "  self.age = age"
#     ],
#     "description": "__init__ 实例化构造函数"
#   },
#
#
#
#      "__iter__": {
#     "prefix": "__iter__=>",
#     "body": [
#       "def __iter__(self):",
#       "  self.a = 1",
#       "  return self"
#     ],
#     "description": "__iter__ method"
#   },
#
#
#   "__next__": {
#     "prefix": "__next__=>",
#     "body": [
#       "def __next__(self):",
#       "  x = self.a",
#       "  self.a += 1",
#       "  return x"
#     ],
#     "description": "__next__ method"
#   },

# %% [markdown]
# "openFile": {
#     "prefix": "file=>openFile",
#     "body": [
#       "f = open('demofile.txt', 'r')",
#       "print(f.read())"
#     ],
#     "description": "open a file"
#   },
#
#
#   "openFileReadLine": {
#     "prefix": "file=>openFileReadLine",
#     "body": [
#       "f = open('demofile.txt', 'r')",
#       "print(f.readline())"
#     ],
#     "description": "Read one line of the file"
#   },
#
#
#   "writeExistFile": {
#     "prefix": "file=>writeExistFile",
#     "body": [
#       "f = open('demofile.txt', 'a')",
#       "f.write('Now the file has one more line!')"
#     ],
#     "description": "Write to an Existing File"
#   },
#
#
#   "writeOwerWrite": {
#     "prefix": "file=>writeOwerWrite",
#     "body": [
#       "f = open('demofile.txt', 'w')",
#       "f.write('Woops! I have deleted the content!')"
#     ],
#     "description": "Open a file and overwrite the content"
#   },
#
#
#   "createFileIfDoesNotExist": {
#     "prefix": "file=>createFileIfDoesNotExist",
#     "body": "f = open('myfile.txt', 'w')",
#     "description": "Create a new file if it does not exist"
#   },
#
#
#   "createFile": {
#     "prefix": "file=>createFile",
#     "body": "f = open('myfile.txt', 'x')",
#     "description": "Create a new file"
#   },
#
#
#   "deleteFile": {
#     "prefix": "file=>deleteFile",
#     "body": [
#       "#import os",
#       "os.remove('demofile.txt')"
#     ],
#     "description": "delete a file"
#   },

# %% [markdown]
#   "class=>_1": {
#     "prefix": "class=>_1",
#     "body": [
#       "class Person:",
#       "    pass  # An empty block",
#       "p = Person()",
#       "print(p)"
#     ],
#     "description": "oop inheritance example"
#   },
#
#
#
#   "class=>inheritance_1": {
#     "prefix": "class=>inheritance_1",
#     "body": [
#       "class Bird:",
#       "",
#       "   def __init__(self):",
#       "     print('Bird is ready')",
#       "",
#       "   def whoisThis(self):",
#       "     print('Bird')",
#       "",
#       "   def swim(self):",
#       "     print('Swim faster')",
#       "",
#       "# child class",
#       "class Penguin(Bird):",
#       "",
#       "   def __init__(self):",
#       "     # call super() function",
#       "     super().__init__()",
#       "     print('Penguin is ready')",
#       "",
#       "   def whoisThis(self):",
#       "     print('Penguin')",
#       "",
#       "   def run(self):",
#       "     print('Run faster')",
#       "",
#       "peggy = Penguin()",
#       "peggy.whoisThis()",
#       "peggy.swim()",
#       "peggy.run()"
#     ],
#     "description": "oop inheritance example"
#   },
#
#
#
#   "class=>inheritance_2": {
#     "prefix": "class=>inheritance_2",
#     "body": [
#       "class SchoolMember:",
#       "    '''Represents any school member.'''",
#       "    def __init__(self, name, age):",
#       "        self.name = name",
#       "        self.age = age",
#       "        print('(Initialized SchoolMember: {})'.format(self.name))",
#       "    def tell(self):",
#       "        '''Tell my details.'''",
#       "        print('Name:{} Age:{}'.format(self.name, self.age), end=' ')",
#       "class Teacher(SchoolMember):",
#       "    '''Represents a teacher.'''",
#       "    def __init__(self, name, age, salary):",
#       "        SchoolMember.__init__(self, name, age)",
#       "        self.salary = salary",
#       "        print('(Initialized Teacher: {})'.format(self.name))",
#       "    def tell(self):",
#       "        SchoolMember.tell(self)",
#       "        print('Salary: {:d}'.format(self.salary))",
#       "class Student(SchoolMember):",
#       "    '''Represents a student.'''",
#       "    def __init__(self, name, age, marks):",
#       "        SchoolMember.__init__(self, name, age)",
#       "        self.marks = marks",
#       "        print('(Initialized Student: {})'.format(self.name))",
#       "    def tell(self):",
#       "        SchoolMember.tell(self)",
#       "        print('Marks: {:d}'.format(self.marks))",
#       "t = Teacher('Mrs. Shrividya', 40, 30000)",
#       "s = Student('Swaroop', 25, 75)",
#       "# prints a blank line",
#       "print()",
#       "members = [t, s]",
#       "for member in members:",
#       "    # Works for both Teachers and Students",
#       "    member.tell()"
#     ],
#     "description": "oop inheritance example"
#   },
#
#
#
#   "class=>with_attribute_1": {
#     "prefix": "class=>with_attribute_1",
#     "body": [
#       "class Parrot:",
#       "",
#       "# class attribute",
#       " species = 'bird'",
#       "",
#       "# instance attribute",
#       " def __init__(self, name, age):",
#       "    self.name = name",
#       "    self.age = age",
#       "",
#       "# instantiate the Parrot class",
#       "blu = Parrot('Blu', 10)",
#       "woo = Parrot('woo', 15)",
#       "",
#       "# access the class attributes",
#       "print('Blu is a {}'.format(blu.__class__.species))",
#       "print('Woo is also a {}'.format(woo.__class__.species))",
#       "# access the instance attributes",
#       "print('{} is {} years old'.format( blu.name, blu.age))",
#       "print('{} is {} years old'.format( woo.name, woo.age))"
#     ],
#     "description": "class with attribute example"
#   },
#
#
#
#   "class=>with_attribute_2": {
#     "prefix": "class=>with_attribute_2",
#     "body": [
#       "class Person:",
#       "    def __init__(self, name):",
#       "        self.name = name",
#       "    def say_hi(self):",
#       "        print('Hello, my name is', self.name)",
#       "p = Person('Swaroop')",
#       "p.say_hi()",
#       "# The previous 2 lines can also be written as",
#       "# Person('Swaroop').say_hi()"
#     ],
#     "description": "class with attribute example"
#   },
#
#
#
#   "class=>with_attribute_3": {
#     "prefix": "class=>with_attribute_3",
#     "body": [
#       "class Robot:",
#       "    '''Represents a robot, with a name.'''",
#       "    # A class variable, counting the number of robots",
#       "    population = 0",
#       "    def __init__(self, name):",
#       "        '''Initializes the data.'''",
#       "        self.name = name",
#       "        print('(Initializing {})'.format(self.name))",
#       "        # When this person is created, the robot",
#       "        # adds to the population",
#       "        Robot.population += 1",
#       "    def die(self):",
#       "        '''I am dying.'''",
#       "        print('{} is being destroyed!'.format(self.name))",
#       "        Robot.population -= 1",
#       "        if Robot.population == 0:",
#       "            print('{} was the last one.'.format(self.name))",
#       "        else:",
#       "            print('There are still {:d} robots working.'.format(",
#       "                Robot.population))",
#       "    def say_hi(self):",
#       "        '''Greeting by the robot.",
#       "        Yeah, they can do that.'''",
#       "        print('Greetings, my masters call me {}.'.format(self.name))",
#       "    @classmethod",
#       "    def how_many(cls):",
#       "        '''Prints the current population.'''",
#       "        print('We have {:d} robots.'.format(cls.population))",
#       "droid1 = Robot('R2-D2')",
#       "droid1.say_hi()",
#       "Robot.how_many()",
#       "droid2 = Robot('C-3PO')",
#       "droid2.say_hi()",
#       "Robot.how_many()",
#       "print('Robots can do some work here.')",
#       "print('Robots have finished their work. So lets destroy them.')",
#       "droid1.die()",
#       "droid2.die()",
#       "Robot.how_many()"
#     ],
#     "description": "class with attribute example"
#   },
#
#
#
#   "class=>with_method_1": {
#     "prefix": "class=>with_method_1",
#     "body": [
#       "class Parrot:",
#       "",
#       "# instance attributes",
#       " def __init__(self, name, age):",
#       "   self.name = name",
#       "   self.age = age",
#       "",
#       "# instance method",
#       " def sing(self, song):",
#       "   return '{} sings {}'.format(self.name, song)",
#       "",
#       " def dance(self):",
#       "   return '{} is now dancing'.format(self.name)",
#       "",
#       "# instantiate the object",
#       "blu = Parrot('Blu', 10)",
#       "# call our instance methods",
#       "print(blu.sing('Happy'))",
#       "print(blu.dance())"
#     ],
#     "description": "class with method example"
#   },
#
#
#
#   "class=>with_method_2": {
#     "prefix": "class=>with_method_2",
#     "body": [
#       "class Person:",
#       "    def say_hi(self):",
#       "        print('Hello, how are you?')",
#       "p = Person()",
#       "p.say_hi()",
#       "# The previous 2 lines can also be written as",
#       "# Person().say_hi()"
#     ],
#     "description": "class with method example"
#   },
#
#
#
#   "class=>encapsulation": {
#     "prefix": "class=>encapsulation",
#     "body": [
#       "class Computer:",
#       "",
#       " def __init__(self):",
#       "   self.__maxprice = 900",
#       "",
#       " def sell(self):",
#       "   print('Selling Price: {}'.format(self.__maxprice))",
#       "",
#       " def setMaxPrice(self, price):",
#       "   self.__maxprice = price",
#       "",
#       "c = Computer()",
#       "c.sell()",
#       "",
#       "# change the price",
#       "c.__maxprice = 1000",
#       "c.sell()",
#       "",
#       "# using setter function",
#       "c.setMaxPrice(1000)",
#       "c.sell()"
#     ],
#     "description": "class encapsulation example"
#   },
#
#
#
#   "class=>polymorphism": {
#     "prefix": "class=>polymorphism",
#     "body": [
#       "class Parrot:",
#       "",
#       " def fly(self):",
#       "   print('Parrot can fly')",
#       "",
#       " def swim(self):",
#       "   print('Parrot can not swim')",
#       "",
#       "class Penguin:",
#       "",
#       " def fly(self):",
#       "   print('Penguin can not fly')",
#       "",
#       " def swim(self):",
#       "   print('Penguin can swim')",
#       "",
#       "# common interface",
#       "def flying_test(bird):",
#       "  bird.fly()",
#       "",
#       "#instantiate objects",
#       "blu = Parrot()",
#       "peggy = Penguin()",
#       "",
#       "# passing the object",
#       "flying_test(blu)",
#       "flying_test(peggy)"
#     ],
#     "description": "class polymorphism example"
#   },
#
#
#
#   "class=>polymorphism": {
#     "prefix": "class=>polymorphism",
#     "body": [
#       "class Parrot:",
#       "",
#       " def fly(self):",
#       "   print('Parrot can fly')",
#       "",
#       " def swim(self):",
#       "   print('Parrot can not swim')",
#       "",
#       "class Penguin:",
#       "",
#       " def fly(self):",
#       "   print('Penguin can not fly')",
#       "",
#       " def swim(self):",
#       "   print('Penguin can swim')",
#       "",
#       "# common interface",
#       "def flying_test(bird):",
#       "  bird.fly()",
#       "",
#       "#instantiate objects",
#       "blu = Parrot()",
#       "peggy = Penguin()",
#       "",
#       "# passing the object",
#       "flying_test(blu)",
#       "flying_test(peggy)"
#     ],
#     "description": "class polymorphism example"
#   }

# %% [markdown]
# "New class": {
#         "prefix": "class",
#         "body": "class ${1:ClassName}(${2:object}):\n\t\"\"\"${3:docstring for $1.}\"\"\"\n\tdef __init__(self, ${4:arg}):\n\t\t${5:super($1, self).__init__()}\n\t\tself.arg = arg\n\t\t$0",
#         "description" : "Code snippet for a class definition."
#     },

# %% [markdown]
# "if": {
#         "prefix": "if",
#         "body": "if ${1:condition}:\n\t${2:pass}$0",
#         "description" : "if语句."
#     },

# %% [markdown]
# "for": {
#         "prefix": "for",
#         "body": "for ${1:value} in ${2:iterable}:\n\t${3:pass}$0",
#         "description" : "Code snippet to create a for loop structure."
#     },

# %% [markdown]
# "while": {
#         "prefix": "while",
#         "body": "while ${1:condition}:\n\t${2:pass}$0",
#         "description" : "创建while循环结构."
#     },

# %% [markdown]
#   "self": {
#         "prefix": ".",
#         "body": "self.$0",
#         "description" : "简写引用对象的self属性."
#     },

# %% [markdown]
# //魔法函数
#
# "__magic__": {
#         "prefix": "__",
#         "body": "__${1:init}__$0",
#         "description" : "Code snippet to create magic methods."
#     },

# %% [markdown]
# //模块声明，只在本py运行，不能再外部调用
#
#  "if __name__ == \"__main__\"": {
#         "prefix": "ifmain",
#         "body": "if __name__ == \"__main__\":\n\t${1:main()}$0",
#         "description" : "Create implicitly all the code at the top level using the __name__ special variable."
#     },

# %% [markdown]
#     "字典推导式kv-for-in": {
#         "prefix": "dc",
#         "body": "{${1:key}: ${2:value} for ${3:key}, ${4:value} in ${5:iterable}}$0",
#         "description" : "Handy and faster way to create dictories based on existing dictionaries."
#     },
#
#
#     "dict-for-in字典迭代": {
#         "prefix": "for key, value",
#         "body": [
#             "for key, value in ${1:字典名}.items():"
#         ],
#         "description": "获取字典的每个kv"
#     },
#
#
#
#     "字典推导式kv-for-in-if过滤": {
#         "prefix": "dci",
#         "body": "{${1:key}: ${2:value} for ${3:key}, ${4:value} in ${5:iterable} if ${6:condition}}$0",
#         "description" : "Handy and faster way to create dictories based on existing dictionaries, with conditional if statement."
#     },

# %% [markdown]
#      "Set集合推导式": {
#         "prefix": "sc",
#         "body": "{${1:value} for ${2:value} in ${3:iterable}}$0",
#         "description" : "Create a set based on existing iterables."
#     },
#
#
#     "Set集合推导式for-in-if过滤": {
#         "prefix": "sci",
#         "body": "{${1:value} for ${2:value} in ${3:iterable} if ${4:condition}}$0",
#         "description" : "Create a set based on existing iterables, with condition if statement."
#     },

# %% [markdown]
#     "生成器推导式for-in": {
#         "prefix": "gc",
#         "body": "(${1:key} for ${2:value} in ${3:iterable})$0",
#         "description" : "Create a generator based on existing iterables."
#     },
#
#
#     "生成器推导式for-in-if过滤": {
#         "prefix": "gci",
#         "body": "(${1:key} for ${2:value} in ${3:iterable} if ${4:condition})$0",
#         "description" : "Create a generator based on existing iterables, with condition if statement."
#     }

# %% [markdown]
# //添加IPython设置debug跟踪
#
#     "PDB set trace": {
#         "prefix": "pdb",
#         "body": "import pdb; pdb.set_trace()$0"
#     },
#     "iPDB set trace": {
#         "prefix": "ipdb",
#         "body": "import ipdb; ipdb.set_trace()$0"
#     },
#     "rPDB set trace": {
#         "prefix": "rpdb",
#         "body": "import rpdb2; rpdb2.start_embedded_debugger('${1:debug_password}')$0"
#     },
#     "PuDB set trace": {
#         "prefix": "pudb",
#         "body": "import pudb; pudb.set_trace()$0"
#     },
#     "IPython set trace": {
#         "prefix": "ipydb",
#         "body": "from IPython import embed; embed()$0"
#     }

# %% [markdown]
# Odoo是一系列开源商业应用程序套装，此套装可满足中小型企业的一切应用需求，例如，企业基本的进销存、采购、销售、MRP生产制造、品保质量保障、企业招聘、员工合同、休假、午餐管理、内部论坛、车队管理、内部聊天IM沟通、客诉追溯管理、CRM客户关系管理、VOIP、E-Shop电子商务、网店、企业官方网站，财务会计、银行对账、资产管理、HR工资管理、预算管理、WMS仓库库存管理、POS街边小摊、社区商店、项目管理、条码、PLM等等等
# 此扩展包含Odoo的代码段，以帮助您更快地开发Odoo模块，并且没有键入错误。
# https://github.com/mstuttgart/vscode-odoo-snippets

# %% [markdown]
# 来源  https://github.com/pynickle/code-snippets

# %% [markdown]
# //导入常用的库
#
# {
#     "numpy": {
#         "prefix": "import numpy",
#         "body": [
#             "import numpy as np"
#         ],
#         "description": "导入numpy as np"
#     },
#     "tensorflow": {
#         "prefix": "import tensorflow",
#         "body": [
#             "import tensorflow as tf"
#         ],
#         "description": "导入tensorflow as tf"
#     },
#     "matplotlib": {
#         "prefix": "from matplotlib.pyplot",
#         "body": [
#             "from matplotlib.pyplot as plt"
#         ],
#         "description": "导入matplotlib as plt"
#     },
#     "tkinter": {
#         "prefix": "import tkinter",
#         "body": [
#             "import tkinter as tk"
#         ],
#         "description": "导入tkinter图形模块 as tk"
#     },
#
#
#     "pathlib": {
#         "prefix": "from pathlib",
#         "body": [
#             "from pathlib import Path"
#         ]，
#         "description": "从路径导入模块"
#     },
#
#
#     "fdt": {
#     "prefix": ["fdt"],
#     "body": ["from dataclasses import dataclass"],
#     "description": "from dataclasses import dataclass"
#   },
# }

# %% [markdown]
# //文件处理
#
# 	"读文件": {
# 		"prefix": "file",
# 	 	"body": [
# 			"with open(r'${1:文件路径}', 'r') as file:",
# 			"\t${2:内容} = file.read()"
# 	 	],
# 	 	"description": "读取某文件"
# 	},
#
# 	"读所有文件": {
# 		"prefix": "file",
# 	 	"body": [
# 			"import os",
# 			"路径 = '.'",
# 			"for 文件名 in os.listdir(路径):",
# 			"\twith open(os.path.join(路径, 文件名)) as 文件:",
# 			"\t\t内容 = 文件.read()"
# 	 	],
# 	 	"description": "读取某目录下所有文件"
# 	}
#
#     "os.walk": {
#         "prefix": "for root, dirs, files",
#         "body": [
#             "for root, dirs, files in os.walk(${1:path}):"
#         ],
#         "description": "use os to walk the path"
#     },
#
#     "files": {
#         "prefix": "for file",
#         "body": [
#             "for file in files:"
#         ],
#         "description": "get every file in files"
#     },

# %% [markdown]
# //尾巴
#
#       "if __name__ == \"__main__\"": {
#     "prefix": ["ifmain","main_entry","if __name__","ifmain"],
#     "body": "if __name__ == \"__main__\":\n\t${1:main()}$0",
#     "description": "当我们调用main()主函数时，不被外部调用."
#   },

# %% [markdown]
# //头
#     "coding = utf-8": {
#         "prefix": "# -*- coding=utf-8 -*-",
#         "body": [
#             "# -*- coding=utf-8 -*-"
#         ],
#         "description" : "set encoding to utf-8 at the top of the file"
#     }

# %% [markdown]
# //breakpoint python 断点
#
#     "breakpoint": {
#         "prefix": "breakpoint",
#         "body": [
#             "breakpoint()"
#         ],
#         "description": "drop you into the debugger"
#     },

# %% [markdown]
#     "issubclass": {
#         "prefix": "issubclass",
#         "body": [
#             "issubclass(${1:判断这个子类}, ${2:父类})"
#         ],
#         "description": "如果类是子类，则返回true“"
#     },

# %% [markdown]
# //标准库
#
#
# {
#     "property": {
#         "prefix": "@property",
#         "body": [
#             "@property"
#         ],
#         "description": "add the property decorator for func"
#     },
#
#
#     "lru_cache": {
#         "prefix": "@lru_cache",
#         "body": [
#             "@lru_cache(${1:maxsize})"
#         ],
#         "description": "use cache to calculate"
#     },
#
#
#     "set_trace": {
#         "prefix": "pdb.set_trace()",
#         "body": [
#             "import pdb; pdb.set_trace()"
#         ],
#         "desscription": "use pdb to debug the program"
#     },
#
#
#     "reader": {
#         "prefix": "reader",
#         "body": [
#             "csv.reader(${1:file})"
#         ],
#         "description": "use csv to read csv file"
#     },
#
#
#     "writer": {
#         "prefix": "csv.writer",
#         "body": [
#             "csv.writer(${1:file})"
#         ],
#         "description": "use csv to write csv file"
#     },
#
#
#     "debug": {
#         "prefix": "logging.debug",
#         "body": [
#             "logging.debug(${1:msg})"
#         ],
#         "description": "logging debug msg"
#     },
#
#
#     "info": {
#         "prefix": "logging.info",
#         "body": [
#             "logging.info(${1:msg})"
#         ],
#         "description": "logging info msg"
#     },
#
#
#     "warning": {
#         "prefix": "logging.warning",
#         "body": [
#             "logging.warning(${1:msg})"
#         ],
#         "description": "logging warning msg"
#     },
#
#
#     "error": {
#         "prefix": "logging.error",
#         "body": [
#             "logging.error(${1:msg})"
#         ],
#         "description": "logging error msg"
#     },
#
#
#     "critical": {
#         "prefix": "logging.critical",
#         "body": [
#             "logging.critical(${1:msg})"
#         ],
#         "description": "logging critical msg"
#     },
#
#
#     "log": {
#         "prefix": "logging.log",
#         "body": [
#             "logging.log(${1:level}, ${2:msg})"
#         ],
#         "description": "logging log msg with level"
#     },
#
#
#
#
#
#     "parser": {
#         "prefix": "argparse.ArgumentParser",
#         "body": [
#             "parser = argparse.ArgumentParser()"
#         ],
#         "description": "create an argument parser from argparse"
#     },
#
#
#     "FileType": {
#         "prefix": "argparse.FileType",
#         "body": [
#             "argparse.FileType"
#         ],
#         "description": "file input type of argparse"
#     },
#
#
#     "args": {
#         "prefix": "parser.parse_args",
#         "body": [
#             "args = parser.parse_args"
#         ],
#         "description": "parse the argument from argparse"
#     },
#
#
#     "add_argument": {
#         "prefix": "parser.add_argument",
#         "body": [
#             "parser.add_argument(${1:name})"
#         ],
#         "description": "add an argument from argparse"
#     },
#
#
#     "add_subparsers": {
#         "prefix": "parser.add_subparsers",
#         "body": [
#             "parser.add_subparsers()"
#         ],
#         "description": "add a subparser of the main parser"
#     },
#
#
#     "add_mutually_exclusive_group": {
#         "prefix": "parser.add_mutually_exclusive_group",
#         "body": [
#             "parser.add_mutually_exclusive_group()"
#         ],
#         "description": "add a mutually exclusive group of the parser"
#     },
#
#
#     "listdir": {
#         "prefix": "os.listdir",
#         "body": [
#             "os.listdir(${1:path})"
#         ],
#         "description": "get all files under the path by os"
#     },
#
#
#     "system": {
#         "prefix": "os.system",
#         "body": [
#             "os.system(${1:command})"
#         ],
#         "description": "execute a command by os"
#     },
#
#
#     "getcwd": {
#         "prefix": "os.getcwd",
#         "body": [
#             "os.getcwd()"
#         ],
#         "description": "get your working directory right now"
#     },
#
#
#     "path.exists": {
#         "prefix": "os.path.exists",
#         "body": [
#             "os.path.exists(${1:path})"
#         ],
#         "description": "check if the path exists by os"
#     },
#
#
#     "exit": {
#         "prefix": "sys.exit",
#         "body": [
#             "sys.exit()"
#         ],
#         "description": "exit the program by sys"
#     },
#
#
#     "print_exc": {
#         "prefix": "traceback.print_exc",
#         "body": [
#             "traceback.print_exc()"
#         ],
#         "description": "print the error during the program"
#     },
#
#
#     "time": {
#         "prefix": "time.time",
#         "body": [
#             "time.time()"
#         ],
#         "description": "get time now"
#     },
#
#
#
#
#
#
#
#     "testmod": {
#         "prefix": "doctest.testmod",
#         "body": [
#             "doctest.testmod()"
#         ],
#         "description": "doctest the file"
#     },
#
#
#     "copy": {
#         "prefix": "copy.copy",
#         "body": [
#             "copy.copy(${1:x})"
#         ],
#         "description": "浅复制x"
#     },
#
#
#     "deepcopy": {
#         "prefix": "copy.deepcopy",
#         "body": [
#             "deepcopy(${1:x})"
#         ],
#         "description": "深复制x"
#     }
#
#
# }

# %% [markdown]
# //正则表达式
#
#
#      "Regular expression match": {
#         "prefix": "regex_match",
#         "body": [
#             "import re",
#             "match = re.match(r\"${1:regex_here}\", ${2:string_here})"
#         ],
#         "description": "Regular expression match"
#     },
#
#
#     "match": {
#         "prefix": "re.match",
#         "body": [
#             "re.match(${1:pattern}, ${2:string})"
#         ],
#         "description": "match a string in the beginning of the string"
#     },
#
#
#     "search": {
#         "prefix": "re.search",
#         "body": [
#             "re.search(${1:pattern}, ${2:string})"
#         ],
#         "description": "scan all of the string and return the result"
#     },
#
#
#     "sub": {
#         "prefix": "re.sub",
#         "body": [
#             "re.sub(${1:pattern}, ${2:repl}, ${3:string})"
#         ],
#         "description": "use the pattern to search in string and replace the result with repl"
#     },
#
#
#     "compile": {
#         "prefix": "re.compile",
#         "body": [
#             "re.compile(${1:pattern})"
#         ],
#         "description": "compile a pattern"
#     },
#
#
#     "findall": {
#         "prefix": "re.findall",
#         "body": [
#             "re.findall(${1:pattern}, ${2:string})"
#         ],
#         "description": "find all string in the string with the pattern"
#     },
#
#
#
#       "Regex replace": {
#         "prefix": "regex_replace",
#         "body": [
#             "import re",
#             "re.sub(${r'1':pattern}, ${2:replacement}, ${3:string})"
#         ],
#         "description": "Regex replace"
#     },

# %% [markdown]
# //声明.jso

# %% [markdown]
# //循环语句
#
#     "for": {
#         "prefix": "for",
#         "body": [
#             "for ${1:item} in ${2:list}:",
#             "    $3"
#         ],
#         "description": "create a loop"
#     },
#
#
#     "for...else": {
#         "prefix": "for",
#         "body": [
#             "for ${1:item} in ${2:list}:",
#             "    $3",
#             "else:",
#             "    $4"
#         ],
#         "description": "create a loop with else"
#     },
#
#
#     "while": {
#         "prefix": "while",
#         "body": [
#             "while ${1:condition}:",
#             "    $2"
#         ],
#         "description": "create a while loop"
#     },
#
#
#     "while...else": {
#         "prefix": "while",
#         "body": [
#             "while ${1:condition}:",
#             "    $2",
#             "else:",
#             "    $3"
#         ],
#         "description": "create a while loop with else"
#     },

# %% [markdown]
# //if语句.json
#
#     "if": {
#         "prefix": "if",
#         "body": [
#             "if ${1:condition}:",
#             "    $2"
#         ],
#         "description": "create a conditional statement"
#
#     },
#
#
#     "if": {
#     "prefix": "if",
#     "body": ["if ${1:condition}:", "\t${2:pass}$0"],
#     "description": "Code snippet for the if statement."
#   },
#
#
#     "If-else": {
#         "prefix": "if_else",
#         "body": [
#             "if $1:",
#             "\t$2",
#             "else:",
#             "\t$3",
#             "$0"
#         ],
#         "description": "If, else example"
#     },
#
#     "ife": {
#     "prefix": "ife",
#     "body": ["if ${1:condition}:", "\t${2:pass}", "else:", "\t$0"],
#     "description": "Code snippet for the if statement."
#     },
#
#
#     "if...elif...else": {
#         "prefix": "if_elseif_else",
#         "body": [
#             "if ${1:condition}:",
#             "\t$2",
#             "elif ${3:condition}:",
#             "\t$4",
#             "else:",
#             "\t$5"
#         ],
#         "description": "a if statement with elif and else condition"
#     },
#
#      "iff": {
#     "prefix": "iff",
#     "body": [
#       "if ${1:condition}:",
#       "\t${2:pass}",
#       "elif:",
#       "\t${3:elif_pass}",
#       "else:",
#       "\t$0"
#     ],
#     "description": "Code snippet for the if statement."
#   },

# %% [markdown]
# "if": {
#     "prefix": "if",
#     "body": [
#       "if ${1:条件}:",
#       "  pass"
#     ],
#     "description": "if语句"
#       },
#
#  "ifelif": {
#     "prefix": "ifelif",
#     "body": [
#       "if ${1:条件}:",
#       "  pass",
#       "elif ${2:条件}:",
#       "  pass"
#     ],
#     "description": "if/elseif 语句"
#       },
#
#  "ifelifelse": {
#     "prefix": "ifelifelse",
#     "body": [
#       "if condition:",
#       "  pass",
#       "elif condition:",
#       "  pass",
#       "else:",
#       "  pass"
#     ],
#     "description": "if/else if/else语句"
#   },
#
#   "ifel": {
#     "prefix": "ifelse",
#     "body": [
#       "if condition:",
#       "  pass",
#       "else:",
#       "  pass"
#     ],
#     "description": "if/else语句"
#   },
#
#   "elif": {
#     "prefix": "else",
#     "body": [
#       "else:",
#       "  pass"
#     ],
#     "description": "else语句"
#   },

# %% [markdown]
# //循环语句
#
#   "el": {
#     "prefix": "el",
#     "body": ["else:", "\t$0"],
#     "description": null
#   },
#
#
#   "ei": {
#     "prefix": ["ei", "eli"],
#     "body": ["elif ${1:condition}:", "\t$0"],
#     "description": null
#   },
#
#
#   "for": {
#     "prefix": ["fr", "for"],
#     "body": ["for ${1:value} in ${2:iterable}:", "\t$0"],
#     "description": "Code snippet to create a for loop structure."
#   },
#
#
#   "fre": {
#     "prefix": ["fre", "fore"],
#     "body": [
#       "for ${1:value} in ${2:iterable}:",
#       "\t${3:loop_action}",
#       "else:",
#       "\t$0"
#     ],
#     "description": "Code snippet to create a for loop structure with additional else on final"
#   },

# %% [markdown]
# // while语句.json
#
#
#   "while": {
#     "prefix": ["wh", "while"],
#     "body": ["while ${1:condition}:", "\t$0"],
#     "description": "Code snippet to create a while loop structure."
#   },
#
#
#   "dowh": {
#     "prefix": "dowh",
#     "body": ["while True:", "\t${1}", "\tif ${0:condition}:", "\t\tbreak"],
#     "description": null
#   },
#
#
#     "While Loop": {
#         "prefix": "while_loop",
#         "body": [
#             "while ${1:condition}:",
#             "\t$2"
#         ],
#         "description": "While Loop"
#     },

# %% [markdown]
# //for in循环
#
#     "Element wise for loop": {
#         "prefix": "for_loop",
#         "body": [
#             "for $1 in ${2:iterable}:",
#             "\t$3"
#         ],
#         "description": "Element wise for loop"
#     },

# %% [markdown]
#     "Break": {
#         "prefix": [
#             "bre",
#             "brea",
#             "break"
#         ],
#         "body": [
#             "break"
#         ],
#         "description": "Break"
#     },
#     "Return": {
#         "prefix": [
#             "return",
#             "retu",
#             "retur"
#         ],
#         "body": [
#             "return"
#         ],
#         "description": "Return"
#     },
#     "Program exit": {
#         "prefix": "program_exit",
#         "body": [
#             "import sys",
#             "sys.exit(0)"
#         ],
#         "description": "Program exit"
#     },
#     "Conditional": {
#         "prefix": [
#             "conditional",
#             "ternary"
#         ],
#         "body": [
#             "${1:true_code} if ${2:condition_check} else ${3:false_code}"
#         ],
#         "description": "Python conditional"
#     },
#     "Try catch": {
#         "prefix": "try_catch",
#         "body": [
#             "try:",
#             "\t$1",
#             "except ${2:BaseException} as ${3:_}:",
#             "\t$4"
#         ],
#         "description": "Try catch finally"
#     },
#     "Try catch finally": {
#         "prefix": "try_catch_finally",
#         "body": [
#             "try:",
#             "\t$1",
#             "except ${2:BaseException} as ${3:_}:",
#             "\t$4",
#             "finally:",
#             "\t$5"
#         ],
#         "description": "Try catch finally"
#     },

# %% [markdown]
#  "ifshort": {
#     "prefix": "ifshort",
#     "body": "${1:符合条件就执行} if ${2:条件} else ${3:不符合条件}",
#     "description": "ifshort语句"
#   },

# %% [markdown]
# //声明.json
#
#     "raise": {
#         "prefix": "raise",
#         "body": [
#             "raise ${1:type}(${2:message})"
#         ],
#         "description": "raise a error yourselves"
#     },
#     "assert": {
#         "prefix": "assert",
#         "body": [
#             "assert ${1:condition}, ${2:message}"
#         ],
#         "description": "check if the condition is right"
#     },
#     "try...except": {
#         "prefix": "try",
#         "body": [
#             "try:",
#             "    $1",
#             "except Exception as e:",
#             "    $2"
#         ],
#         "description": "try something might be wrong"
#     },
#
#
#
#     "with": {
#         "prefix": "with",
#         "body": [
#             "with ${1:do} as ${2:name}:",
#             "    $3"
#         ],
#         "description": "a more beautiful than try"
#     },
#     "global": {
#         "prefix": "global",
#         "body": [
#             "global ${1:attr}"
#         ],
#         "description": "change the attr global"
#     },
#     "nonlocal": {
#         "prefix": "nonlocal",
#         "body": [
#             "nonlocal ${1:attr}"
#         ],
#         "description": "use attr outside"
#     },
#
#     "yield": {
#         "prefix": "yield",
#         "body": [
#             "yield ${1:thing}"
#         ],
#         "description": "yield to make lazy calculation"
#     }

# %% [markdown]
#    "lambda": {
#     "prefix": "lambda",
#     "body": "lambda ${1:任意参数如x或i}:${2:操作参数的返回值}",
#     "description": "lambda函数可以接受任意数量的参数，但只能有一个表达式."
#   },

# %% [markdown]
# //字符串模块
#
# {
#     ".isupper": {
#         "prefix": ".isupper",
#         "body": [
#             ".isupper()"
#         ],
#         "description": "检查是否所有字符串都是upper str"
#     },
#     ".islower": {
#         "prefix": ".islower",
#         "body": [
#             ".islower()"
#         ],
#         "description": "check if all of the string is lower str"
#     },
#     ".lower": {
#         "prefix": ".lower",
#         "body": [
#             ".lower()"
#         ],
#         "description": "lower all the str in the string"
#     },
#     ".upper": {
#         "prefix": ".upper",
#         "body": [
#             ".upper()"
#         ],
#         "description": "upper all the str in the string"
#     },
#     ".capitalize": {
#         "prefix": ".capitalize",
#         "body": [
#             ".capitalize()"
#         ],
#         "description": "capitalize the string"
#     },
#     ".zfill": {
#         "prefix": ".zfill",
#         "body": [
#             ".zfill(${1:width})"
#         ],
#         "description": "fill the zero with blank to make the length turn into width"
#     },
#     ".isspace": {
#         "prefix": ".isspace",
#         "body": [
#             ".isspace()"
#         ],
#         "description": "check if the string contains only space"
#     },
#     ".isdigit": {
#         "prefix": ".isdigit",
#         "body": [
#             ".isdigit()"
#         ],
#         "description": "return True if it is a digit string"
#     },
#     ".isprintable": {
#         "prefix": ".isprintable",
#         "body": [
#             ".isprintable()"
#         ],
#         "description": "check if it is a printable object"
#     },
#     ".isnumeric": {
#         "prefix": ".isnumeric",
#         "body": [
#             ".isnumeric()"
#         ],
#         "description": "检查字符串是否只有数字"
#     },
#     ".endswith": {
#         "prefix": ".endswith",
#         "body": [
#             ".endswith(${1:string})"
#         ],
#         "description": "return True if the string ends with another string"
#     },
#     ".isidentifier": {
#         "prefix": ".isidentifier",
#         "body": [
#             ".isidentifier()"
#         ],
#         "description": "check if the string is a valid python identifier"
#     },
#     ".title": {
#         "prefix": ".title",
#         "body": [
#             ".title()"
#         ],
#         "description": "return a version of the string where each word is titlecased."
#     }
# }

# %% [markdown]
# //定义类class.json
#
#   "cl": {
#     "prefix": "cl",
#     "body": [
#       "class ${1:ClassName}(${2:object}):",
#       "\t\"\"\"${3:docstring for $1}\"\"\"",
#       "\tdef __init__(self, ${4:arg}):",
#       "\t\t${5:super($1, self).__init__()}",
#       "\t\tself.$4 = $4",
#       "\t\t${0}"
#     ],
#     "description": null
#   },
#
#
#   "cla": {
#     "prefix": "cla",
#     "body": ["class ${1:class_name}:", "\t\"\"\"${0:description}\"\"\""],
#     "description": null
#   },
#
#
#   "clai": {
#     "prefix": "clai",
#     "body": [
#       "class ${1:class_name}:",
#       "\t\"\"\"${2:description}\"\"\"",
#       "\tdef __init__(self, ${3:args}):",
#       "\t\t${0}"
#     ],
#     "description": null
#   },
#
#
#   "claip": {
#     "prefix": "claip",
#     "body": [
#       "class ${1:class_name}:",
#       "\t\"\"\"${2:description}\"\"\"",
#       "\tdef __init__(self, ${3:args}):",
#       "\t\t${4}",
#       "\n",
#       "\tdef __post_init__(self, ${5:args}):",
#       "\t\t${0}"
#     ],
#     "description": null
#   },
#
#
#   "dtcl": {
#     "prefix": ["dtcl", "dtcls"],
#     "body": ["@dataclass", "class ${1:class_name}:", "\t${0}"],
#     "description": null
#   },
#
#
#   "dtcla": {
#     "prefix": ["dtcla"],
#     "body": [
#       "@dataclass",
#       "class ${1:class_name}:",
#       "\t\"\"\"${2:description}\"\"\"",
#       "\t${0}"
#     ],
#     "description": null
#   },
#
#
#   "dtclap": {
#     "prefix": ["dtclap"],
#     "body": [
#       "@dataclass",
#       "class ${1:class_name}:",
#       "\t\"\"\"${2:description}\"\"\"",
#       "\t${3}",
#       "\tdef __post_init__(self, ${4:args}):",
#       "\t\t${0}"
#     ],
#     "description": null
#   },

# %% [markdown]
# //定义函数.json
#
#     "定义函数": {
#         "prefix": ["function","hanshu","def"],
#         "body": [
#           "def ${1:函数名}(${2:参数}):",
#           "\"\"\" ${3:函数说明}\"\"\""
#           "\t${4:函数体}$0"
#         ],
#         "description": "定义函数"
#       },
#
#     "定义类方法": {
#         "prefix": ["defs","defself","leifangfa"],
#         "body": [
#           "def ${1:name}(self, ${2:arg}):\n",
#           "\"\"\" ${3:类方法说明}\"\"\""
#           "\t${3:pass}$0",
#         "description" : "定义类方法."
#         },
#
#     "New property": {
#         "prefix": "property",
#         "body": "@property\ndef ${1:foo}(self):\n    \"\"\"${2:The $1 property.}\"\"\"\n    ${3:return self._$1}\n@${4:$1}.setter\ndef ${5:$1}(self, value):\n    ${6:self._$1} = value",
#         "description": "property函数的作用是在新式类中返回属性值"
#     },
#
#      "New froperty": {
#         "prefix": "property",
#         "body": "def ${1:foo}():\n    doc = \"${2:The $1 property.}\"\n    def fget(self):\n        ${3:return self._$1}\n    def fset(self, value):\n        ${4:self._$1 = value}\n    def fdel(self):\n        ${5:del self._$1}\n    return locals()\n$1 = property(**$1())$0",
#         "description" : ""
#     },
#
#
#
#
#  "df, def": {
#     "prefix": ["df", "def"],
#     "body": [
#       "def ${1:fname}(${2:args):",
#       "\t\"\"\"${3:docstring for $1}\"\"\"",
#       "\t${0}"
#     ],
#     "description": null
#   },
#
#
#   "dff, deff": {
#     "prefix": ["dff", "deff"],
#     "body": ["def ${1:fname}(self, ${2:args}):", "\t${0}"],
#     "description": null
#   },
#
#   //静态方法
#      "staticmethod": {
#         "prefix": "staticmethod",
#         "body": "staticmethod(function)",
#         "description": "在class类中@staticmethod返回函数的静态方法，静态方法无需实例化：类.静态方法() ，实例化后调用：类实例化 = 类() -- 类实例化.静态方法() "
#         },
#       "Static method": {
#         "prefix": ["static_method","jingtai","sdf", "sdef"],
#         "body": [
#             "@staticmethod",
#             "def ${1:函数名}($2:参数):",
#             "\t${0}"
#         ],
#         "description": "静态方法"
#     },
#
#
#   "pr": {
#     "prefix": ["pr"],
#     "body": ["@property", "def ${1:foo}(self):", "\t${2:return self._$1}"],
#     "description": "New property: get"
#   },
#
#
#   "prs": {
#     "prefix": ["prs"],
#     "body": [
#       "@property",
#       "def ${1:foo}(self):",
#       "\t${2:return self._$1}",
#       "@${4:$1}.setter",
#       "def ${5:$1}(self, value):",
#       "\t${6:self._$1} = value"
#     ],
#     "description": "New property: get and set via decorator"
#   },

# %% [markdown]
# //异常处理
#
# "try:except:": {
#     "prefix": "try",
#     "body": "try:\n\t${1:pass}\nexcept ${2:Exception} as ${3:e}:\n\t${4:raise $3}$0",
#     "description": "Code Snippet for a try and except blocks."
#   },
#
#
#   "try:except:else:finally": {
#     "prefix": "tryef",
#     "body": "try:\n\t${1:pass}\nexcept${2: ${3:Exception} as ${4:e}}:\n\t${5:raise}\nelse:\n\t${6:pass}\nfinally:\n\t${7:pass}$0",
#     "description": "Code Snippet for a try/except/finally with else statement."
#   },
#
#
#   "try:except:else": {
#     "prefix": "trye",
#     "body": "try:\n\t${1:pass}\nexcept ${2:Exception} as ${3:e}:\n\t${4:raise $3}\nelse:\n\t${5:pass}$0",
#     "description": "Code Snippet for a try/except with else statement."
#   },
#
#
#   "try:except:finally": {
#     "prefix": "tryf",
#     "body": "try:\n\t${1:pass}\nexcept ${2:Exception} as ${3:e}:\n\t${4:raise $3}\nfinally:\n\t${5:pass}$0",
#     "description": "Code Snippet for a try/except/finally."
#   },

# %% [markdown]
# //声明
#
#   "__magic__": {
#     "prefix": "__",
#     "body": "__${1:init}__$0",
#     "description": "Code snippet to create magic methods."
#   },
#
#   "with": {
#     "prefix": ["wth", "with"],
#     "body": ["with ${1:expr}:", "\t${0}"],
#     "description": null
#   },
#   "with as": {
#     "prefix": ["wta", "wath"],
#     "body": ["with ${1:expr} as ${2:var}:", "\t${0:${VISUAL}}"],
#     "description": null
#   },
#   "awith": {
#     "prefix": "awith",
#     "body": ["async with ${1:expr} as ${2:var}:", "\t${0:${VISUAL}}"],
#     "description": null
#   },
#   "adef": {
#     "prefix": "adef",
#     "body": [
#       "async def ${1:fname}(${2:`indent('.') ? 'self' : ''`}):",
#       "\t\"\"\"${3:docstring for $1}\"\"\"",
#       "\t${0}"
#     ],
#     "description": null
#   },
#   "adeff": {
#     "prefix": "adeff",
#     "body": [
#       "async def ${1:fname}(${2:`indent('.') ? 'self' : ''`}):",
#       "\t${0}"
#     ],
#     "description": null
#   },
#   "defi": {
#     "prefix": "defi",
#     "body": ["def __init__(self, ${1:args}):", "\t${0}"],
#     "description": null
#   },
#   "defm": {
#     "prefix": "defm",
#     "body": ["def ${1:mname}(self, ${2:arg}):", "\t${0}"],
#     "description": null
#   },
#   "adefm": {
#     "prefix": "adefm",
#     "body": ["async def ${1:mname}(self, ${2:arg}):", "\t${0}", ""],
#     "description": null
#   },
#   "property": {
#     "prefix": "property",
#     "body": [
#       "def ${1:foo}():",
#       "\tdoc = \"${2:The $1 property.}\"",
#       "\tdef fget(self):",
#       "\t\t${3:return self._$1}",
#       "\tdef fset(self, value):",
#       "\t\t${4:self._$1 = value}",
#       "\tdef fdel(self):",
#       "\t\t${0:del self._$1}",
#       "\treturn locals()",
#       "$1 = property(**$1())"
#     ],
#     "description": null
#   },
#   "cutf8": {
#     "prefix": "cutf8",
#     "body": ["# -*- coding: utf-8 -*-"],
#     "description": null
#   },
#   "clatin1": {
#     "prefix": "clatin1",
#     "body": ["# -*- coding: latin-1 -*-"],
#     "description": null
#   },
#   "cascii": {
#     "prefix": "cascii",
#     "body": ["# -*- coding: ascii -*-"],
#     "description": null
#   },
#   "ld": {
#     "prefix": "ld",
#     "body": ["${1:var} = lambda ${2:vars} : ${0:action}"],
#     "description": null
#   },
#   "ret": {
#     "prefix": "ret",
#     "body": ["return ${0}"],
#     "description": null
#   },
#   ".": {
#     "prefix": ".",
#     "body": ["self."],
#     "description": null
#   },

# %% [markdown]
# "try Try/Except": {
#     "prefix": "try",
#     "body": [
#       "try:",
#       "\t${1:${VISUAL}}",
#       "except ${2:Exception} as ${3:e}:",
#       "\t${0:raise $3}"
#     ],
#     "description": null
#   },
#   "trye Try/Except/Else": {
#     "prefix": "trye",
#     "body": [
#       "try:",
#       "\t${1:${VISUAL}}",
#       "except ${2:Exception} as ${3:e}:",
#       "\t${4:raise $3}",
#       "else:",
#       "\t${0}"
#     ],
#     "description": null
#   },
#   "tryf Try/Except/Finally": {
#     "prefix": "tryf",
#     "body": [
#       "try:",
#       "\t${1:${VISUAL}}",
#       "except ${2:Exception} as ${3:e}:",
#       "\t${4:raise $3}",
#       "finally:",
#       "\t${0}"
#     ],
#     "description": null
#   },
#   "tryef Try/Except/Else/Finally": {
#     "prefix": "tryef",
#     "body": [
#       "try:",
#       "\t${1:${VISUAL}}",
#       "except ${2:Exception} as ${3:e}:",
#       "\t${4:raise $3}",
#       "else:",
#       "\t${5}",
#       "finally:",
#       "\t${0}"
#     ],
#     "description": null
#   },
#
#
#
#   "\"": {
#     "prefix": "\"",
#     "body": ["\"\"\"${0:doc}", "\"\"\""],
#     "description": null
#   },
#
#
#   "a=": {
#     "prefix": "a=",
#     "body": ["self.assertEqual(${0}, ${1})"],
#     "description": null
#   },
#
#
#   "test": {
#     "prefix": "test",
#     "body": [
#       "def test_${1:description}(${2:`indent('.') ? 'self' : ''`}):",
#       "\t${0}"
#     ],
#     "description": null
#   },
#
#
#   "testcase": {
#     "prefix": "testcase",
#     "body": [
#       "class ${1:ExampleCase}(unittest.TestCase):",
#       "",
#       "\tdef test_${2:description}(self):",
#       "\t\t${0}"
#     ],
#     "description": null
#   },
#
#
#   "tgwt": {
#     "prefix": "tgwt",
#     "body": ["# given: ${1}", "# when: ${2}", "# then: ${3}"],
#     "description": null
#   },
#
#
#   "fut": {
#     "prefix": "fut",
#     "body": ["from __future__ import ${0}"],
#     "description": null
#   },
#
#
#   "getopt": {
#     "prefix": "getopt",
#     "body": [
#       "try:",
#       "\t# Short option syntax: \"hv:\"",
#       "\t# Long option syntax: \"help\" or \"verbose=\"",
#       "\topts, args = getopt.getopt(sys.argv[1:], \"${1:short_options}\", [${2:long_options}])",
#       "",
#       "except getopt.GetoptError, err:",
#       "\t# Print debug info",
#       "\tprint str(err)",
#       "\t${3:error_action}",
#       "",
#       "for option, argument in opts:",
#       "\tif option in (\"-h\", \"--help\"):",
#       "\t\t${0}",
#       "\telif option in (\"-v\", \"--verbose\"):",
#       "\t\tverbose = argument"
#     ],
#     "description": null
#   },
#
#
#   "addp": {
#     "prefix": "addp",
#     "body": ["parser = ${VISUAL:argparse.}ArgumentParser()"],
#     "description": null
#   },
#
#
#   "addsp": {
#     "prefix": "addsp",
#     "body": [
#       "${0:sub_parser} = parser.add_subparsers().add_parser(\"${1:name}\")"
#     ],
#     "description": null
#   },
#
#
#   "addarg": {
#     "prefix": "addarg",
#     "body": [
#       "parser.add_argument(\"${0:short_arg}\", \"${1:long_arg}\", default=${2:None}, help=\"${3:Help text}\")"
#     ],
#     "description": null
#   },
#
#
#   "addnarg": {
#     "prefix": "addnarg",
#     "body": [
#       "parser.add_argument(\"${0:arg}\", nargs=\"${1:*}\", default\"${2:None}, help=\"${3:Help text}\")"
#     ],
#     "description": null
#   },
#
#
#   "addaarg": {
#     "prefix": "addaarg",
#     "body": [
#       "parser.add_argument(\"${0:arg}\", \"${1:long_arg}\", action=\"${2:store_true}\", default=${3:False}, help=\"${4:Help text}\")"
#     ],
#     "description": null
#   },
#
#
#   "pargs": {
#     "prefix": "pargs",
#     "body": ["\"${VISUAL:return }\"parser.parse_args()", ""],
#     "description": null
#   },
#
#
#   "glog": {
#     "prefix": "glog",
#     "body": ["import logging", "LOGGER = logging.getLogger(${0:__name__})"],
#     "description": null
#   },
#
#
#   "le": {
#     "prefix": "le",
#     "body": ["LOGGER.error(${0:msg})"],
#     "description": null
#   },
#
#
#   "lg": {
#     "prefix": "lg",
#     "body": ["LOGGER.debug(${0:msg})"],
#     "description": null
#   },
#
#
#   "lw": {
#     "prefix": "lw",
#     "body": ["LOGGER.warning(${0:msg})"],
#     "description": null
#   },
#
#
#   "lc": {
#     "prefix": "lc",
#     "body": ["LOGGER.critical(${0:msg})"],
#     "description": null
#   },
#
#
#   "li": {
#     "prefix": "li",
#     "body": ["LOGGER.info(${0:msg})"],
#     "description": null
#   },
#
#
#   "epydoc": {
#     "prefix": "epydoc",
#     "body": [
#       "\"\"\"${1:Description}",
#       "",
#       "@param ${2:param}: ${3: Description}",
#       "@type  $2: ${4: Type}",
#       "",
#       "@return: ${5: Description}",
#       "@rtype : ${6: Type}",
#       "",
#       "@raise e: ${0: Description}",
#       "\"\"\""
#     ],
#     "description": null
#   },
#   "dol": {
#     "prefix": "dol",
#     "body": [
#       "def ${1:__init__}(self, *args, **kwargs):",
#       "    super(${0:ClassName}, self).$1(*args, **kwargs)"
#     ],
#     "description": null
#   },
#   "kwg": {
#     "prefix": "kwg",
#     "body": ["self.${1:var_name} = kwargs.get('$1', ${2:None})"],
#     "description": null
#   },
#   "lkwg": {
#     "prefix": "lkwg",
#     "body": ["${1:var_name} = kwargs.get('$1', ${2:None})"],
#     "description": null
#   },
#   "args": {
#     "prefix": "args",
#     "body": ["*args${1:,}${0}"],
#     "description": null
#   },
#   "kwargs": {
#     "prefix": "kwargs",
#     "body": ["**kwargs${1:,}${0}"],
#     "description": null
#   },
#   "akw": {
#     "prefix": "akw",
#     "body": ["*args, **kwargs${1:,}${0}", ""],
#     "description": null
#   },
#   "lcp list comprehension": {
#     "prefix": "lcp",
#     "body": ["[${1} for ${2} in ${3:${VISUAL}}]${0}", ""],
#     "description": null
#   },
#   "dcp dict comprehension": {
#     "prefix": "dcp",
#     "body": ["{${1}: ${2} for ${3} in ${4:${VISUAL}}}${0}", ""],
#     "description": null
#   },
#   "scp set comprehension": {
#     "prefix": "scp",
#     "body": ["{${1} for ${2} in ${3:${VISUAL}}}${0}", ""],
#     "description": null
#   },
#   "contain \"methods for emulating a container type\" b": {
#     "prefix": "contain",
#     "body": [
#       "def __len__(self):",
#       "\t${1:pass}",
#       "",
#       "def __getitem__(self, key):",
#       "\t${2:pass}",
#       "",
#       "def __setitem__(self, key, value):",
#       "\t${3:pass}",
#       "",
#       "def __delitem__(self, key):",
#       "\t${4:pass}",
#       "",
#       "def __iter__(self):",
#       "\t${5:pass}",
#       "",
#       "def __reversed__(self):",
#       "\t${6:pass}",
#       "",
#       "def __contains__(self, item):",
#       "\t${7:pass}",
#       ""
#     ],
#     "description": null
#   },
#   "context \"context manager methods\" b": {
#     "prefix": "context",
#     "body": [
#       "def __enter__(self):",
#       "\t${1:pass}",
#       "",
#       "def __exit__(self, exc_type, exc_value, traceback):",
#       "\t${2:pass}",
#       ""
#     ],
#     "description": null
#   },
#   "attr \"methods for customizing attribute access\" b": {
#     "prefix": "attr",
#     "body": [
#       "def __getattr__(self, name):",
#       "\t${1:pass}",
#       "",
#       "def __setattr__(self, name, value):",
#       "\t${2:pass}",
#       "",
#       "def __delattr__(self, name):",
#       "\t${3:pass}",
#       ""
#     ],
#     "description": null
#   },
#   "desc \"methods implementing descriptors\" b": {
#     "prefix": "desc",
#     "body": [
#       "def __get__(self, instance, owner):",
#       "\t${1:pass}",
#       "",
#       "def __set__(self, instance, value):",
#       "\t${2:pass}",
#       "",
#       "def __delete__(self, instance):",
#       "\t${3:pass}",
#       ""
#     ],
#     "description": null
#   },
#   "cmp \"methods implementing rich comparison\"": {
#     "prefix": "cmp",
#     "body": [
#       "def __eq__(self, other):",
#       "\t${1:pass}",
#       "",
#       "def __ne__(self, other):",
#       "\t${2:pass}",
#       "",
#       "def __lt__(self, other):",
#       "\t${3:pass}",
#       "",
#       "def __le__(self, other):",
#       "\t${4:pass}",
#       "",
#       "def __gt__(self, other):",
#       "\t${5:pass}",
#       "",
#       "def __ge__(self, other):",
#       "\t${6:pass}",
#       "",
#       "def __cmp__(self, other):",
#       "\t${7:pass}",
#       ""
#     ],
#     "description": null
#   },
#   "repr \"methods implementing string representation\"": {
#     "prefix": "repr",
#     "body": [
#       "def __repr__(self):",
#       "\t${1:pass}",
#       "",
#       "def __str__(self):",
#       "\t${2:pass}",
#       "",
#       "def __unicode__(self):",
#       "\t${3:pass}",
#       ""
#     ],
#     "description": null
#   },
#   "uni": {
#     "prefix": "uni",
#     "body": ["def __unicode__(self):", "\t${0:representation}"],
#     "description": null
#   },
#   "docs": {
#     "prefix": "docs",
#     "body": [
#       "\"\"\"",
#       "File: ${1:`vim_snippets#Filename('$1.py', 'foo.py')`}",
#       "Author: `g:snips_author`",
#       "Email: `g:snips_email`",
#       "Github: `g:snips_github`",
#       "Description: ${0}",
#       "\"\"\"",
#       ""
#     ],
#     "description": null
#   },
#   "sk \"skip unittests\" b": {
#     "prefix": "sk",
#     "body": ["@unittest.skip(${1:skip_reason})", ""],
#     "description": null
#   }

# %% [markdown]
# //调试,断点
#
#   "pdb": {
#     "prefix": "pdb",
#     "body": ["__import__('pdb').set_trace()"],
#     "description": null
#   },
#   "bpdb": {
#     "prefix": "bpdb",
#     "body": ["__import__('bpdb').set_trace()"],
#     "description": null
#   },
#   "ipdb": {
#     "prefix": "ipdb",
#     "body": ["__import__('ipdb').set_trace()"],
#     "description": null
#   },
#   "iem": {
#     "prefix": "iem",
#     "body": ["__import__('IPython').embed()"],
#     "description": null
#   },
#   "rpdb": {
#     "prefix": "rpdb",
#     "body": ["__import__('rpdb').set_trace()"],
#     "description": null
#   },
#   "wdb": {
#     "prefix": "wdb",
#     "body": ["__import__('wdb').set_trace()"],
#     "description": null
#   },
#
#
#   "ptpython": {
#     "prefix": "ptpython",
#     "body": [
#       "__import__('ptpython.repl', fromlist=('repl')).embed(globals(), locals(), vi_mode=${1:False}, history_filename=${2:None})"
#     ],
#     "description": null
#   },
#   "pudb": {
#     "prefix": "pudb",
#     "body": ["__import__('pudb').set_trace()"],
#     "description": null
#   },
#   "nosetrace": {
#     "prefix": "nosetrace",
#     "body": ["__import__('nose').tools.set_trace()"],
#     "description": null
#   },
#   "pprint": {
#     "prefix": "pprint",
#     "body": ["__import__('pprint').pprint(${1})"],
#     "description": null
#   },

# %% [markdown]
# {
#     "Console Log": {
#         "prefix": "log",
#         "body": "logging.info($1)",
#         "description": "将信息消息记录到控制台。."
#     },
#
#
#     "Console Log - Info": {
#         "prefix": "logi",
#         "body": "logging.info($1)",
#         "description": "将信息消息记录到控制台."
#     },
#
#
#     "Console Log - Warning": {
#         "prefix": "logw",
#         "body": "logging.warning($1)",
#         "description": "将警告消息记录到控制台."
#     },
#
#
#     "Console Log - Error": {
#         "prefix": "loge",
#         "body": "logging.error($1)",
#         "description": "将错误消息记录到控制台."
#     },
#
#
#     "Method Definition": {
#         "prefix": "def",
#         "body": [
#             "def $1():",
#             "    \"\"\" $2",
#             "",
#             "    Parameters:",
#             "        None",
#             "",
#             "    Returns:",
#             "        None",
#             "    \"\"\"",
#             "",
#             "    return"
#         ],
#         "description": "使用docstring的方法定义."
#     }
# }

# %% [markdown]
#     "string interpolation": {
#         "prefix": "string_interpolation",
#         "body": [
#             "f'$1 {${2:expression_here}} $3'"
#         ],
#         "description": "string interpolation"
#     },

# %% [markdown]
#  "Bitwise or": {
#         "prefix": "bitwise_or",
#         "body": [
#             "$1 | $2"
#         ],
#         "description": "Bitwise or"
#     },
#
#        "Bitwise and": {
#         "prefix": "bitwise_and",
#         "body": [
#             "$1 & $2"
#         ],
#         "description": "Bitwise and"
#     },
#
#      "Bitwise exclusive or": {
#         "prefix": "bitwise_xor",
#         "body": [
#             "$1 ^ $2"
#         ],
#         "description": "Bitwise exclusive or"
#     },
#
#
#        "Bitwise negation": {
#         "prefix": "bitwise_negation",
#         "body": [
#             "~$1"
#         ],
#         "description": "Bitwise negation"
#     },

# %% [markdown]
#     "Bit shift left": {
#         "prefix": "bit_shift_left",
#         "body": [
#             "${1:要移动的东西} << ${2:移位量}"
#         ],
#         "description": "位左移"
#     },
#
#
#     "Bit shift right": {
#         "prefix": "bit_shift_right",
#         "body": [
#             "${1:要移动的东西} >> ${2:移位量}"
#         ],
#         "description": "位右移"
#     },

# %% [markdown]
#     "Return long standing variable method": {
#         "prefix": "return_long_standing_variable_method",
#         "body": [
#             "def ${1:function_name}(self, $2):",
#             "\treturned = ${3:None}",
#             "\t$4",
#             "\treturn returned"
#         ],
#         "description": "Return long standing variable method"
#     },

# %% [markdown]
#    "Get command ouput": {
#         "prefix": "get_command_output",
#         "body": [
#             "impport subprocess",
#             "${2:output_variable_here} = subprocess.run([${1:command_list_here}], stdout=subprocess.PIPE).stdout.decode('utf-8')"
#         ],
#         "description": "获取输出命令"
#     },

# %% [markdown]
#     "Run command": {
#         "prefix": "run_command",
#         "body": [
#             "import subprocess",
#             "subprocess.run([${1:command_list_here}]"
#         ],
#         "description": "运行命令"
#     },

# %% [markdown]
#    "Method": {
#         "prefix": ["method","shili"],
#         "body": [
#             "def ${1:method_name}(self, $2):",
#             "\t$3"
#         ],
#         "description": "定义实例方法"
#     },

# %% [markdown]
#     "Filter": {
#         "prefix": "filter",
#         "body": [
#             "$1 = ${2:collection_to_cast_to}(filter(${3:function_to_apply}, ${4:list_of_inputs}))"
#         ],
#         "description": "filter"
#     },

# %% [markdown]
#     "Reduce": {
#         "prefix": "reduce",
#         "body": [
#             "from functools import reduce",
#             "$1 = reduce(${2:function_to_apply}, ${3:list_of_inputs})"
#         ],
#         "description": "Reduce"
#     },

# %% [markdown]
#     "Base class": {
#         "prefix": ["base_class","class"],
#         "body": [
#             "class $1:",
#             "\t$2"
#         ],
#         "description": "Base class"
#     },
#
#
#     "Inheritance class": {
#         "prefix": ["inheritance_class","jichenglei","jichengclass"],
#         "body": [
#             "class ${1:这个类名}(${2:父类}):",
#             "\t$3"
#         ],
#         "description": "继承类class"
#     },

# %% [markdown]
# //基本语法.json
#
#  "井号注释": {
# 	"prefix": ["jing","ji"],
# 	"body": [
#            " #",
# 	],
# 	"description": "井号注释"
#     },
#
#     "Block comment": {
#         "prefix": ["duozhushi","block_comment"],
#         "body": [
#             "$BLOCK_COMMENT_START$1$BLOCK_COMMENT_END"
#         ],
#         "description": "多行注释块"
#     },
#
#
#     //括号
#         "小括号": {
#         "prefix": ["xiao","xiaokuohao"],
#         "body": [
#                "($0)",
#         ],
#         "description": "小括号"
#         },
#
#     "Cast": {
#         "prefix": "cast",
#         "body": [
#             "$1($TM_SELECTED_TEXT)"
#         ],
#         "description": "小括号"
#         },
#
#         "中括号": {
#         "prefix": ["zhong","zhongkuohao"],
#         "body": [
#                "[$0]",
#         ],
#         "description": "中括号"
#         },
#
#     "大括号": {
#         "prefix": ["da","dakuohao"],
#         "body": [
#                "{$0}",
#         ],
#         "description": "大括号"
#         },
#
#         //引号
#
#         "单引号": {
#         "prefix": ["dan","danyinhao"],
#         "body": [
#                "'$0'",
#         ],
#         "description": "单引号"
#         },
#
#         "双引号": {
#         "prefix": ["shuang","shuangyinhao"],
#         "body": [
#                "\"$0\"",
#         ],
#         "description": "双引号"
#         },
#
#     //分号
#      "分号": {
#         "prefix": ["fen","fenhao"],
#         "body": [
#                ";",
#         ],
#         "description": "语句之间使用分号;分割可以在同一行中使用多条语句"
#         },
#
#
#   //打印
#     "print": {
#     "prefix": ["print","pr"],
#     "body": "print(${1:输出多个对象时逗号分隔}, sep=${2:间隔符默认值是一个空格}, end=${3:结尾符默认值是换行符\n}, file=${4:要写入的文件对象}, flush=${5:输出是否被缓存通常决定于file，但如果 flush 关键字参数为 True，流会被强制刷新})",
#     "description": "打印输出"
#     },
#
#     //打印指定间隔符结尾符
#         "print": {
#         "prefix": ["print","pr222"],
#         "body": "print(${1:},${2:},sep='${3:间隔符}', end='${4:结尾符}')",
#         "description": "打印输出"
#         },
#
#
#
#
#   //打印传导的变量
# 	"print": {
# 		"prefix": "printf",
# 		"body": "print(f\"{${1:变量名}}\")",
# 		"description": "打印输出",
# 	  },
#         "print": {
# 		"prefix": "printfor",
# 		"body": "print(\"{}\".format(${1:变量名}))",
# 		"description": "打印输出",
# 	  },
#
#
#
#    "打印两个空行": {
# 		"prefix": "ppp",
# 		"body": [
# 			"print('\\n'*2, $1)",
# 		],
# 		"description": "打印两个空行，input("\n\n按下 enter 键后退出。")"
# 	}
#
#      "print防转义": {
#         "prefix": ["printr","printrr"],
#         "body": [
#                "print(r'${1:原始字符串，防止转义}')",
#         ],
#         "description": "print防转义"
#         },
#
#         "pprint": {
#         "prefix": "pprint.pprint",
#         "body": [
#             "pprint.pprint(${1:str})"
#         ],
#         "description": "打印漂亮的字符串，import pprint"
#     },
#
#     "打印字符串": {
# 		"prefix": "printstr",
# 		"body": [
# 			"print(\"$0\")",
# 		],
# 		"description": "打印字符串"
# 	}
#
#     "打印多行字符串": {
# 		"prefix": ["printstr","duoprint"],
# 		"body": [
# 			"print(\"\"\"\n$0\n\t\"\"\")",
# 		],
# 		"description": "打印多行字符串"
# 	},
#
#
#      "保留字": {
#         "prefix": ["reserved_words","baoliuzi","baoliuguanjianzi"],
#         "body": [
#             "$BLOCK_COMMENT_START",
#             "True - 布尔值为真.",
#             "False - 布尔值为假.",
#             "class - 定义类",
#             "finally - 与try一起使用…除了block做最后一件事，不管在它之前执行了什么",
#             "is - 在Python中用于测试对象标识。当==运算符用于测试两个变量是否相等时，则用于测试两个变量是否引用同一对象",
#             "return - 函数的返回值",
#             "None - 这是null的替代，表示对象引用不指向任何内容",
#             "continue - 将停止循环执行并返回并重新评估循环条件/开始新的迭代.",
#             "for - 用于循环。通常我们在知道要循环的次数时使用",
#             "lambda - 用于创建匿名函数（没有名称的函数）。它是不包含返回语句的内联函数。它由计算并返回的表达式组成.",
#             "try - 创建异常处理块.",
#             "def - 定义一个函数.",
#             "from - from…import用于将特定属性或函数导入当前命名空间.",
#             "nonlocal - 用于声明嵌套函数（函数中的函数）中的变量不是它的本地变量，这意味着它位于外部包含函数中",
#             "while - 创建while循环，此循环将一直运行，直到满足其开头的条件为止.",
#             "and - 逻辑和.",
#             "del - 用于删除对对象的引用.",
#             "global - 用于声明函数内部的变量是全局的（函数外部）.",
#             "not - 逻辑not.",
#             "with - 用于在上下文管理器定义的方法中包装代码块的执行.",
#             "as - 用于在导入模块时创建别名.",
#             "elif - 当“如果”分支失败时要检查的分支.",
#             "if - 检查条件，如果条件为真，则在其主体中执行代码.",
#             "or - 逻辑或or.",
#             "yield - 在函数内部使用，如返回语句。但收益率返回一个生成器.",
#             "assert - 测试调试测试条件.",
#             "else - “if”块中的条件失败时执行的一段代码.",
#             "import - 用于将模块导入当前命名空间.",
#             "pass - 是Python中的空语句。执行时什么都不会发生。它用作占位符.",
#             "break - 退出循环.",
#             "except - 用于捕获在try块中运行的程序时发生的特定异常.",
#             "in - 用于测试序列（列表、元组、字符串等）是否包含值.",
#             "raise - 是用来破例的.",
#             "$BLOCK_COMMENT_END"
#         ],
#         "description": "保留关键字"
#     },
#
#
#
#     // 导入模块
#
#     "import": {
#         "prefix": ["import","im","imp"],
#         "body": "import ${1:库或模块}$0",
#         "description" : "导入库或模块,将整个模块(somemodule)导入"
#     },
#
#     "import...as": {
#         "prefix": ["import","imas"],
#         "body": [
#             "import ${1:module} as ${2:name}"
#         ],
#         "description": "导入模块并重命名"
#     },
#
#
#     "from ... import ...": {
#         "prefix": ["fim","from"],
#         "body": "from ${1:库或模块} import ${2:全部导入, division库, 打印函数, unicode文本}$0",
#         "description" : "从某个模块中导入某个函数.从某个模块中导入多个函数逗号隔开"
#     },
#
#
#
#     "from...import...as": {
#         "prefix": ["fimas"],
#         "body": [
#             "from ${1:module} import ${2:thing} as ${3:name}"
#         ],
#         "description": "从一个库中导入模块并重命名"
#     },
#
#
#     "from ... import ...": {
#         "prefix": ["fim","from"],
#         "body": "from ${1:库或模块} import *\n$0",
#         "description" : "将某个模块中的全部函数导入"
#     },
#
#
#     //python头文件模板例子
#     "HEADER":{
#         "prefix": ["header","tou"],
#         "body": [
#         "#!/usr/bin/env python3",
#         "# -*- encoding: utf-8 -*-",
#         "'''",
#         "@File    :   $TM_FILENAME",
#         "@Time    :   $CURRENT_YEAR/$CURRENT_MONTH/$CURRENT_DATE $CURRENT_HOUR:$CURRENT_MINUTE:$CURRENT_SECOND",
#         "# $TM_FILENAME",
#         "@Author  :   Huang Taiziming ",
#         "@Version :   1.0",
#         "@Contact :   ii6uu99@163.com",
#         "@License :   (C)Copyright 2017-2018, Liugroup-NLPR-CASIA",
#         "@Desc    :   None",
#
#         "'''",
#         "",
#         "# here put the import lib",
#         "$0"
#     ],
#     "description": "py编写头部信息"
#     }
#
#
#
# "全局变量": {
#     "prefix": ["global","quanju"],
#     "body": [
#            "Global ${1:变量名}",
#     ],
#     "description": "全局变量"
#     },
#
#     "局部变量": {
#     "prefix": ["local","jubu"],
#     "body": [
#            "Local ${1:变量名}",
#     ],
#     "description": "局部变量"
#     },

# %% [markdown]
# //编码.json
#
#     "绝对值": {
# 		"prefix": "jueduizhi",
# 		"body": [
# 		  "abs(${1:数值})"
# 		],
# 		"description": "数字绝对值"
# 	  },
#
#       	"转为accii码": {
# 		"prefix": "ascii2",
# 		"body": [
# 			"ascii(${1:要转换的字符串数字})"
# 		],
# 		"description": "转换为ascii"
# 	  },
#
# //数字的集中类型：十进制，二进制，十六进制，八进制
#
#       	"bin": {
# 		"prefix": "bin",
# 		"body": [
# 			"bin(${1:数字})"
# 		],
# 		"description": "数字转为二进制"
# 	  },
#
#    "hex": {
#     "prefix": "hex",
#     "body": "hex(${1:数值})",
#     "description": "将10进制整数转换成16进制，以字符串形式表示"
#   },
#
#    "oct": {
#     "prefix": "oct",
#     "body": "oct(${1:整数})",
#     "description": "将一个整数转换成8进制字符串"
#   },

# %% [markdown]
# //控制台需要用户输入input
#
#     "输入input": {
#         "prefix": "input",
#         "body": [
#         "input(\"${1:提示信息}\")",
#         "$0"
#          ],
#         "description": "允许用户输入"
#     },
#
#
# 	"输入浮点数": {
# 		"prefix": ["fi","inputf"],
# 		"body": [
# 			"float(input())",
# 			"$0"
# 		],
# 		"description": "输入浮点数."
# 	},
#
#     "输入整数": {
# 		"prefix": ["fi","inputint"],
# 		"body": [
# 			"int(input())",
# 			"$0"
# 		],
# 		"description": "快速输入整数."
# 	},
#
# 	"快速输入一行整数": {
# 		"prefix": "li",
# 		"body": [
# 			"[int(k) for k in input().split()]",
# 			"$0"
# 		],
# 		"description": "快速输入一行整数."
# 	},
#
# 	"输入一行浮点数": {
# 		"prefix": "lf",
# 		"body": [
# 			"[float(k) for k in input().split()]",
# 			"$0"
# 		],
# 		"description": "快速输入一行浮点数."
# 	},
#
# 	"I/O template": {
# 		"prefix": "io",
# 		"body": [
# 			"import sys",
# 			"sys.stdin=open('input.txt', 'r')",
# 			"sys.stdout=open('output.txt', 'w')",
# 			"",
# 			"$0"
# 		],
# 		"description": "I/O text files for test cases."
# 	},

# %% [markdown]
# //异常处理
#
# "try:except:": {
#         "prefix": "try",
#         "body": "try:\n\t${1:pass}\nexcept ${2:Exception} as ${3:e}:\n\t${4:raise $3}$0",
#         "description" : "Code Snippet for a try and except blocks."
#     },
#
#
#     "try:except:else:finally": {
#         "prefix": "tryef",
#         "body": "try:\n\t${1:pass}\nexcept${2: ${3:Exception} as ${4:e}}:\n\t${5:raise}\nelse:\n\t${6:pass}\nfinally:\n\t${7:pass}$0",
#         "description" : "Code Snippet for a try/except/finally with else statement."
#     },
#
#
#     "try:except:else": {
#         "prefix": "trye",
#         "body": "try:\n\t${1:pass}\nexcept ${2:Exception} as ${3:e}:\n\t${4:raise $3}\nelse:\n\t${5:pass}$0",
#         "description" : "Code Snippet for a try/except with else statement."
#     },
#
#      "try:except:finally": {
#         "prefix": "tryf",
#         "body": "try:\n\t${1:pass}\nexcept ${2:Exception} as ${3:e}:\n\t${4:raise $3}\nfinally:\n\t${5:pass}$0",
#         "description" : "Code Snippet for a try/except/finally."
#     },
#
#
#
#       "tryexcept": {
#         "prefix": "trye=>",
#         "body": [
#           "try:",
#           "\t${1:执行代码}",
#           "except:",
#           "\t${2:触发错误后执行或print}')"
#         ],
#         "description": "try-except异常处理"
#       },
#
#
#       "try-except-finally": {
#         "prefix": "tryef=>",
#         "body": [
#           "try:",
#           "  print(x)",
#           "except:",
#           "  print('Something went wrong')",
#           "finally:",
#           "  print('The try except is finished')"
#         ],
#         "description": "tryexceptfinally method"
#       },
#
#
#
#      "except": {
#         "prefix": "except Exception",
#         "body": [
#             "except Exception as e:"
#         ],
#         "description": "together with try:except"
#     },

# %% [markdown]
# //tkinter画图库
#
#     "Import Tkinter": {
#         "prefix": "imtk",
#         "body": "import Tkinter as tk$0",
#     "description": "导入Tkinter图形库"
#     },
#
#  "tk空白视窗": {
#     "prefix": ["tkwindow","kongbaichuang"],
#     "body": [
#      "# 第1步，实例化object，建立窗口window",
#     "${1:实例化窗口名} = tk.Tk()",
#     "# 第2步，给窗口的可视化起名字",
#     "${1:实例化窗口名}.title('窗口标题')",
#     "# 第3步，设定窗口的大小(长 * 宽)",
#     "${1:实例化窗口名}.geometry('500x300')  # 这里的乘是小x",
#     "",
#     "#最后一步，主窗口循环显示",
#     "${1:实例化窗口名}.mainloop()",
#     ],
#     "description": "tk空白视窗"
#     },
#
#
#
#     "Root configuration": {
#         "prefix": "config",
#         "body": "config(menu=$1)$0",
#     "description": "  "
#     },
#
#
#
#     "Button": {
#         "prefix": ["button","tk.Button","anniu"],
#         "body": [
#             "tk.Button(${1:root}, text=\"${2:msg}\")$0"
#         ],
#         "description": "在tk屏幕上创建一个按钮,按钮控件；在程序中显示按钮"
#     },
#
#
#
#
#
#
#
#
#     "entry": {
#         "prefix": ["tk.Entry","entry","shurukongjian"],
#         "body": [
#             "tk.Entry(${1:root})$0"
#
#         "description": "输入控件；用于显示简单的文本内容"
#     },
#
#
#     "Grid": {
#         "prefix": "grid",
#         "body": "grid(row=$1, colomn=$2)$0",
#     "description": "  "
#     },
#
#
#
#     "Sticky": {
#         "prefix": "sticky",
#         "body": "sticky=tk.$0",
#     "description": "  "
#     },
#
#
#     "Check button": {
#         "prefix": "checkbutton",
#         "body": "tk.Checkbutton(${1:root}, text=\"$2\")$0",
#     "description": "  "
#     },
#
#     "Main loop": {
#         "prefix": "mainloop",
#         "body": "mainloop()$0",
#     "description": "  "
#     },
#
#
#     "Pack": {
#         "prefix": "pack",
#         "body": "pack($1)$0",
#     "description": "  "
#     },
#
#
#     "Side": {
#         "prefix": "side",
#         "body": "side=tk.$0",
#     "description": "  "
#     },
#
#
#     "Bind": {
#         "prefix": "bind",
#         "body": "bind(\"<Button-${1:1}>\", ${2:fxn})$0",
#     "description": "  "
#     },
#
#
#     "Menu": {
#         "prefix": "menu",
#         "body": "tk.menu(${1:root})$0",
#     "description": " 菜单控件；显示菜单栏,下拉菜单和弹出菜单 "
#     },
#
#
#
#     "Add cascade": {
#         "prefix": "addcascade",
#         "body": "add_cascade(label=\"$1\", menu=$2)$0",
#     "description": "  "
#     },
#
#
#     "Add command": {
#         "prefix": "addcommand",
#         "body": "add_command(label=\"$1\", command=$2)$0",
#     "description": "  "
#     },
#
#
#     "Add seperator": {
#         "prefix": "addseperator",
#         "body": "add_separator()$0",
#     "description": "  "
#     },
#
#
#
#     "Root configuration": {
#         "prefix": "config",
#         "body": "config(menu=$1)$0",
#     "description": "  "
#     },
#
#
#     "Button": {
#         "prefix": "button",
#         "body": "tk.Button(${1:root}, text=\"$2\")$0",
#     "description": "  "
#     },
#
#         "Label": {
#         "prefix": ["tk.Label","label","biaoqian"],
#         "body": [
#             "tk.Label(${1:root}, text=\"${2:msg}\")$0"
#         ],
#         "description": "标签控件；可以显示文本和位图"
#     },
#
#
#     "Frame": {
#         "prefix": "frame",
#         "body": "tk.Frame(${1:root})$0",
#     "description": " 框架控件；在屏幕上显示一个矩形区域，多用来作为容器 "
#     },
#
#
#     "Entry": {
#         "prefix": "entry",
#         "body": "tk.Entry(${1:root})$0",
#     "description": "  "
#     },
#
#
#     "Grid": {
#         "prefix": "grid",
#         "body": "grid(row=$1, colomn=$2)$0",
#     "description": "  "
#     },
#
#
#     "Sticky": {
#         "prefix": "sticky",
#         "body": "sticky=tk.$0",
#     "description": "  "
#     },
#
#
#     "Check button": {
#         "prefix": "checkbutton",
#         "body": "tk.Checkbutton(${1:root}, text=\"$2\")$0",
#     "description": " 多选框控件；用于在程序中提供多项选择框 "
#     },
#
#
#     "Main loop": {
#         "prefix": "mainloop",
#         "body": "mainloop()$0",
#     "description": "  "
#     },
#
#
#     "Pack": {
#         "prefix": "pack",
#         "body": "pack($1)$0",
#     "description": "  "
#     },
#
#
#     "Side": {
#         "prefix": "side",
#         "body": "side=tk.$0",
#     "description": "  "
#     },
#
#
#     "Bind": {
#         "prefix": "bind",
#         "body": "bind(\"<Button-${1:1}>\", ${2:fxn})$0",
#     "description": "  "
#     },
#
#
#
#
#
#     "Add cascade": {
#         "prefix": "addcascade",
#         "body": "add_cascade(label=\"$1\", menu=$2)$0",
#     "description": "  "
#     },
#
#
#     "Add command": {
#         "prefix": "addcommand",
#         "body": "add_command(label=\"$1\", command=$2)$0",
#     "description": "  "
#     },
#
#
#     "Add seperator": {
#         "prefix": "addseperator",
#         "body": "add_separator()$0",
#     "description": "  "
#     }
#
#
#         "tkinter.Tk": {
#         "prefix":"root = tkinter.Tk()",
#         "body": [
#             "root = tk.Tk()"
#         ],
#         "description": "create a tkinter window"
#     },
#
#
#
#
#
#
#
#
#
#
#     "pack": {
#         "prefix": ".pack",
#         "body": [
#             ".pack()"
#         ],
#         "description": "pack a tkinter object"
#     },
#
#
#     "root.mainloop": {
#         "prefix": "root.mainloop",
#         "body": [
#             "root.mainloop()"
#         ],
#         "description": "let tkinter window run"
#     },

# %% [markdown]
# “ python的全部内置异常”：{
#   “ prefix”：“ yichang”，
#   “身体”： [
#     “ ArithmeticError算术错误”，
#     “ AssertionError断言语句，当assert语句失败时将被引发”，
#     “ AttributeError属性错误，当属性引用或赋值失败时将被引发，如元祖.append，元组是不可变对象”，
#     “ BlockingIOError当一个操作会被某个设置为非双向操作的对象（例如多个）所造成的双重时将被引发”，
#     “ BrokenPipeError当试图引发另一端已被关闭的管道，或者试图写入已关闭写入的足以时将被引发”
#     “” BufferError当与常规相关的操作无法执行时将被引发“
#     “ BytesWarning与bytes和bytearray相关的警告的基类”，
#     “ ChildProcessError当一个子进程上的操作失败时将被引发”
#     “ ConnectionAbortedError线程连接中止，当连接尝试被对端中止时将被引发”
#     “ ConnectionError连接错误，与连接相关问题的基类”，
#     “ ConnectionRefusedError当连接尝试被对端拒绝时将被引发”
#     “ ConnectionResetError当连接被对端重置时将被引发”，
#     “不推荐使用的警告，所用的方法或特性已经过时”，
#     “ EnvironmentError环境出错”，
#     “ EOFError当input（）函数未读取任何数据即达到文件结束条件（EOF）时将被引发”，
#     “异常异常错误”，
#     “ FileExistsError当试图创造一个已存在的文件或目录时将被引发”
#     “ FileNotFoundError当所请求的文件或目录不存在时将被引发”，
#     “ FloatingPointError浮点计算错误”，
#     “ FutureWarning如果所发出的警告是针对Python所编写的应用的最终用户的，则以此作为与已弃用特性相关警告的基类”，
#     “ ImportError导入模块失败的时候”，
#     “ ImportWarning引入警报，与在模块引入中可能的错误相关的警告的基类”，
#     “ IndentationError缩进错误”，
#     “ IndexError索引错误，使用的索引不存在，常索引超过序列范围，序列中没有此索引（index）”，
#     “ InterruptedError当系统调用被输入信号中断时将被引发”
#     “ IOError文件确实不存在，文件写入时遇到IOError错误，权限问题导致”，
#     “ IsADirectoryError当请求对一个目录执行文件操作将被引发”时，
#     “ KeyError在重新读取字典中的键和值时，如果键不存在，就会触发KeyError错误”，
#     “ LookupError此基基类用于派生当映射或序列所使用的键或索引无效时引发的异常”，
#     “ MemoryError内存溢出（可通过删除对象释放内存）”，
#     “ ModuleNotFoundError没找到模块错误”，
#     “ NameError试图访问的局部或变量变量不存在，变量没有被定义”，
#     “ NotADirectoryError当请求对一个非目录对象执行目录操作时将被引发”
#     “ NotImplementedError在用户自定义的基类中，抽象方法适合在其要求所派生类重载该方法，或者在其要求所开发的类中提示具体实现尚待添加时引发此异常”
#     “ OSError操作系统产生的异常（例如打开一个不存在的文件或“磁盘已满”）”，
#     “ OverflowError数值运算超出最大限制，重叠错误”，
#     “ PendingDeprecationWarning对于已过时并预计在未来弃用，但当前尚未弃用的特性相关警告的基类”，
#     “ PermissionError权限错误，文件找到，或者被占用，或者无权限访问，或者打开的不是文件，另一个一个目录”，
#     “ ProcessLookupError未找到进程错误，当给定的进程不存在时将被引发”
#     “ RecursionError递归错误，超过了最大递归深度”，
#     “” ReferenceError在使用weakref.proxy（）函数所创建的弱引用来试图访问一个已经被垃圾回收机制回收了的对象“，
#     “ ResourceWarning与资源使用相关的警告的基类”，
#     “ RuntimeError当检测到一个不归属于任何其他类别的错误时将被引发”
#     “ RuntimeWarning与模糊的运行时行为相关的警告的基类”，
#     “ StopAsyncIteration必须由一个异步迭代器对象的__anext __（）方法来引发以停止迭代操作”，
#     “ StopIteration next（）和iterator的__next __（）方法所引发，表示该迭代器不能产生没有更多的值”，
#     “ SyntaxError语法错误，代码形式错误”，
#     “ SyntaxWarning与模糊的语法相关的警告的基类”，
#     “ SystemError当python解释器发现内部错误，但情况看起来尚未严重到要放弃所有希望时将被引发”
#     “ TabError选项卡和空格混用”，
#     “ TimeoutError当一个系统函数发生系统级超时的情况下将被引发”
#     “ TypeError不同类型间的无效操作，如print（'字符串'+ int整数）”，
#     “ UnboundLocalError当在函数或方法中对某个局部变量进行引用，但该变量变量绑定任何值时将被引发（NameError的子类）”，
#     “ UnicodeError Unicode相关的错误（ValueError的子类）”，
#     “ UnicodeEncodeError Unicode编码时的错误（UnicodeError的子类）”，
#     “ UnicodeDecodeError Unicode解码时的错误（UnicodeError的子类）”，
#     “ UnicodeTranslateError Unicode转换时的错误（UnicodeError的子类）”，
#     “ UnicodeWarning与Unicode相关的警告的基类”，
#     “用户警告用户代码所产生的警告的基类”，
#     ““ ValueError当操作或函数接收到具有正确类型但值不适合的参数，并且情况不能用更精确的异常来描述时将被引发”，
#     “警告警告类”，
#     “ WindowsError 3没有这个路径，5权限问题，13该文档被其他程序占用，123路径语法有误，145多在删除非空目录时出现”，
#     “ ZeroDivisionError除数为零”
#   ]，
#   “ description”：“ python的全部内置异常”
# }

# %% [markdown]
#     "运算符": {
#         "prefix": ["yunsuanfu","fuhao"],
#         "body": [
#          "从高优先级到低优先级运算符：",
#         "",
#         "** 指数 (最高优先级)",
#         "",
#         "~ 按位翻转、+正号、 -负号",
#         "",
#         "*乘、 /除、 %取余、 //取整除",
#         "",
#         "+加法 、-减法",
#         "",
#         "移位运算符 >>右移 、<<左移",
#         "",
#         "& 按位与运算符：参与运算的两个值,如果两个相应位都为1,则该位的结果为1,否则为0",
#         "",
#         "^按位异或运算符：当两对应的二进位相异时，结果为1 ----",
#         "|按位或运算符：只要对应的二个二进位有一个为1时，结果位就为1。",
#         "",
#         "比较运算符  <=小于等于 、<小于 、>大于、 >=大于等于",
#         "",
#         "等于运算符  ==等于、 !=不等于",
#         "",
#         "赋值运算符 = %= /= //= -= += *= **=",
#         "",
#         "身份运算符 等同于id(x) == id(y) 或者 id(x) ！= id(y) ：is、 is not",
#         "",
#         "成员运算符 in、 not in",
#         "",
#         "逻辑运算符 and、 or、 not",
#         "",
#
#         ],
#         "description": "运算符"
#         },

# %% [markdown]
# //学习方法库helping.json
#
# "查询方法属性类异常": {
#   "prefix": "hall",
#   "body": [
#     "import helping",
#     "helping.info(${1:输入库名，缺省是内置的函数方法类异常})"
#   ],
#   "description": "查询方法属性类异常"
# },
#
# "查询函数": {
#   "prefix": "hhanshu",
#   "body": [
#     "import helping",
#     "helping.functions(${1:输入库名，缺省是内置的函数方法类异常})"
#   ],
#   "description": "查询函数"
# },
#
#
# "查询方法": {
#   "prefix": "hfangfa",
#   "body": [
#     "import helping",
#     "helping.methods(${1:输入库名，缺省是内置的函数方法类异常})"
#   ],
#   "description": "查询方法"
# },
#
# "查询属性": {
#   "prefix": "hshuxing",
#   "body": [
#     "import helping",
#     "helping.attributes(${1:输入库名，缺省是内置的函数方法类异常})"
#   ],
#   "description": "查询属性"
# },
#
# "查询类": {
#   "prefix": "hlei",
#   "body": [
#     "import helping",
#     "helping.classes(${1:输入库名，缺省是内置的函数方法类异常})"
#   ],
#   "description": "查询类"
# },
#
# "查询异常": {
#   "prefix": "hyichang",
#   "body": [
#     "import helping",
#     "helping.exceptions(${1:输入库名，缺省是内置的函数方法类异常})"
#   ],
#   "description": "查询异常"
# },

# %% [markdown]
# 分支控制 if else
# 循环控制 for while
# 序列：列表集合元祖
# 输入输出 input print 文件
# 错误和异常
#
# if语句
# bool表达式
# defind
# dypeerror
#
# import time
# time.sleep()
#
# ocr识别软件下载免费  https://github.com/AnyListen/tianruoocr/releases

# %% [markdown]
# #打印今天的日期
# from datetime import datetime
# dt=datetime.now()
# print(f'今天是:{dt.year}年{dt.month}月{dt.day}日{dt.hour}:{dt.minute}:{dt.second}')
# print(dt.strftime('今天是：%Y年%m月%d日%H：%M：%S'))

# %% [markdown]
# 休息
#
# import time
# time.sleep(1)

# %% [markdown]
# ①Bool表达式-最终的值只能是：真True，假False
# ②常见形式：
# ①常量：True，False
# ②比较运算
# ③复合运算：and or not
# ④其他的推断③闰年的例子①能被4整除
# ②但如果是100的倍数，也必须是400的倍数
#
# ①检测
# ①数字：0为False，其他为True
# ②字符串：空的为False，其他为True
# ③ None
# ④列表，字典，元组：空的为False，其他为True
#
# ①python-m pip install 模块名称

# %% [markdown]
# 退出程序方式
#
# while (True):
#     cmd=input()
#     if(cmd=='88'):
#         print('88')
#         break;
# """下面的语句不执行"""

# %% [markdown]
# 用时
# begin_time = time.time()
# end_time = time.time()
# used_time = end_time - begin_time #用了多少时间
# used_time = round(used_time, 2) #保留两位小数
# print(f'共用时{int(used_time)}秒')
#
#
#
# def calc_time(begin_time):
# 	end_time = time.time()
# 	used_time = end_time - begin_time #用了多少时间
# 	used_time = round(used_time, 2) #保留两位小数
# 	print(f'共用时{used_time}秒')
# 	return used_time

# %% [markdown]
# while(True):
# 	if(条件语句)):
# 		#执行语句
# 		break; #跳出循环
# 	else:
# 		#否则执行的语句

# %% [markdown]
# #while:根据一个判断条件；for是循环一个已知的列表
# is_right = False
# for i in range(3):
# 	guess = int(input('我想好了1个1-10之间的数字，你猜是几？'))
# 	if(answer == guess):
# 		is_right = True
# 		break;
#     else:
#         #否则执行的语句
# if(is_right):
# 	print('你猜对了！👌')
# 	print('游戏结束！886')
# else:
# 	print('你用完了猜测次数，你失败了❌')

# %% [markdown]
# print('太大了', end='，')

# %% [markdown]
# import sys
# guess_limit = int(sys.argv[1]) #接收用户输入的第一个参数 python *.py 参数1

# %% [markdown]
# con = input('要继续玩，输入y，否则直接回车：')
# 	if(con != 'y'):
# 		print('886...')
# 		break #退出游戏

# %% [markdown]
# #以元祖的形式保存战绩到列表中
# 	scores = [] #战绩
# 	scores.append((cycle, is_right, used_time))
# 	print(scores)
#
# #
# #保存战绩
# 	scores.append((cycle, is_right, used_time))
# 	best_score = min(scores, key=lambda x:x[2] if x[1] else 9999)
# 	print('=========战绩============')
# 	for _cycle, _is_right, _used_time in scores:
# 		label = '✌️ ' if(_is_right) else '❌ '
# 		best_label = '👄' if(_cycle == best_score[0] and best_score[1]) else '' #设定最好的标记
# 		print(f'{_cycle}轮，{label}，{_used_time}{best_label}')
# 	print('========================')

# %% [markdown]
# for i in range(guess_limit):
#     #执行一次，次数就减少1
#     if(i < guess_limit-1):
# 			print('请继续猜：')  #

# %% [markdown]
# while(True):
# 	cycle += 1

# %% [markdown]
# import sys
# try:
# 	guess_limit = int(sys.argv[1]) #最多猜测次数
# 	print(a)
# except ValueError: #异常处理模块
# 	guess_limit = 4
# 	print('输入次数有错，使用默认值：4')
# except NameError:
# 	print('Name error, ignore')

# %% [markdown]
# is_right = False
# 	#while:根据一个判断条件；for是循环一个已知的列表
# 	for i in range(guess_limit):
# 		guess = int(input('我想好了1个1-10之间的数字，你猜是几？'))
# 		if(answer == guess):
# 			is_right = True
# 			break;
# 		elif(guess > answer):
# 			print('太大了', end='，')
# 		else:
# 			print('太小了', end='，')
#
# 		if(i < guess_limit-1):
# 			print('请继续猜：')
# 	#处理结果
# 	if(is_right):
# 		print('你猜对了！👌')
# 	else:
# 		print('你用完了猜测次数，你失败了❌')

# %% [markdown]
# import sys
# try:
# 	guess_limit = int(sys.argv[1]) #最多猜测次数
# 	print(a)
# except ValueError: #异常处理模块
# 	guess_limit = 4
# 	print('输入次数有错，使用默认值：4')
# except NameError:
# 	print('Name error, ignore')

# %% [markdown]
# for i in range(限制次数):
# 		try:  #直到用户输入正确
# 			guess = int(input('我想好了1个1-10之间的数字，你猜是几？'))
# 		except:
# 			print('别乱说，输入1-10之间的数字')
# 			continue
# 		if(i < 限制次数-1):
# 			print('请继续猜：')

# %% [markdown]
# import sys
# def input_limit():
# 	try:
# 		limit = int(sys.argv[1]) #最多猜测次数
# 	except ValueError: #异常处理模块
# 		limit = 4
# 		print('输入次数有错，使用默认值：4')
# 	return limit
#
# guess_limit = input_limit()

# %% [markdown]
# def input_limit():
# 	try:
# 		limit = int(sys.argv[1]) #最多猜测次数
# 	except ValueError: #异常处理模块
# 		limit = 4
# 		print('输入次数有错，使用默认值：4')
# 	return limit

# %% [markdown]
# #局部变量local和全局变量global
# #1. 局部变量：def和class内定义的变量
# #2. 全局变量：在脚本内（def和class外）定义的变量
# #3. 局部变量只有在局部可用
# #4. 全局变量可以在global和函数内访问
# #5. 局部变量如果和全局变量重名，局部变量优先使用
# #6. 全局是指在当前文件（模块）内全局
# #7. 在函数内改写全局变量，需要用global关键词

# %% [markdown]
# #匿名函数 - lambda
# #1. 没有名称的一行的函数，大部分时候是一次性的函数
# #2. 不用def，也可以被复制
#
# numbers = [2, 4, 5, 6, 8, 3, 6]
#
# def process(numbers, 匿名函数calc):
# 	for n in numbers:
# 		print(calc(n), end=' ')
# 	print()
#
# f = lambda x:11 if x%3==0 else x
#
# process(numbers, f)
#
# process(numbers, lambda x:x*2)
#
# process(numbers, lambda x:x*x)

# %% [markdown]
# 列表包含元祖，指定数值来排序
# min([(2,8),(5,1)],key=lambda x:x[1])

# %% [markdown]
# 1#561For语法结构和基于数字（range）的循环
# 562基于列表list，元祖tuple的循环5#
# 563跳过单次循环6#564马上退出循环
# 7#565嵌套循环
# 8#566一次性退出嵌套循环9
# #567 显示循环的index和值10
# #568循环的本质-到底可以基于什么循环11
# #569实现自己的可循环类

# %% [markdown]
# Jupyter常用快捷键
# ·运行程序：shift+enter，ctrl+enter，alt +enter
# ·删除单元格：命令状态下，按两次字母d
# ·删除整行：编辑状态下，ctrl+d
# ·切换到命令状态，按Esc；切换到编辑状态，按enter
# ·标题模式：命令状态下，按字母m
#
# 它的本质其实是一个笔记本
# 它可以将代码、带格式的文本、图片、表格、公式、视频、动画、地圈、交互式控件、等等，都整合在一个文档中
#
# pip installjupyter-i https://pypi.tuna.tsinghua.edu.cn/simple/

# %% [markdown]
# #563跳过单次循环
# for x in [3，4，5，8，9]：
# if（x%3==0）：
#    continue#跳过本次循环后面的语句，马上进入下一轮循环print（x）
# print（x*5)
# print（x*x）
# print（x*x*x）

# %% [markdown]
# #564马上退出所有循环
# numbers=[3，4，5，8，9]
# for x in numbers：
# if（x==5）：
# break    #直接退出循环
# print（x）
# print（"程序结束了…"）

# %% [markdown]
# #565嵌套循环
# names=['zhangsan','lisi','wangwu']
# for name in names:
#     for n in name:
#         print(n)
# print("---")

# %% [markdown]
# #566一次性退出嵌套循环
# names=['zhangsan','lisi','wangwu']
# is_found = False #表示是否找到了
# for name in names:
# 	if(is_found):
# 		break
# 	for n in name:
# 		if(n =='s'):
# 			is_found =True
# 			break
# 		print(n)

# %% [markdown]
# #569实现自己的可循环类-随机数循环
# import random
# class RandomCount:
# 	def __iter__(self):
# 		return self
# 	def __next__(self):
# 		r=random.randint(1，10)
# 		if(r==9):
# 			raise StopIteration
# 		return r
# rc=RandomCount()
# for s in rc:
# 	print(s)

# %% [markdown]
# #570再看While循环
# while（a>b）：
#     break
#     continueI

# %% [markdown]
# 异常处理 内置异常
# https://docs.python.org/zh-cn/3/library/exceptions.html
#
# 处理异常
# https://docs.python.org/zh-cn/3/tutorial/errors.html#handling-exceptions

# %% [markdown]
# #函数的3要素：名字，参数，返回值
# def bmi（height，weight）：
#     return weight/（height*height）
# print（bmi（1.78，72））

# %% [markdown]
# Puthun函数的参数详解
# def f（a，h，/，c，d，*，e，f，**kwarg）
#
# def  f(a,b,/,c,d,*,e,f,**kwargs):
#     print(a,b,c,d,e,f)
# def  f(a,b,c,d,*args,**kwargs):
#     print(a,b,c,d,args,kwargs)
#
#
# 1#1.位置参数2#
# def calc（a，b，c）：
#     print（a*a+2*b+c）
# calc（3，5，8）#位置参数
#
# 2关键词参数
# calc（c=8，b=5，a=3）
# 3#混搭
# 先位置，后关键词
# cal（3，b=5，c=8）
#
# 4#4.强制关键词参数，星号后面是强制关键词参数
# def c2（d，*，a，b，c）：
#     print（a*a+2*b+c）
# c2（6，a=3，b=5，c=8）
#
#
# #5.默认参数，先非默认参数，再默认参数
# def c3（a，b=5，c=8）：
# print（a*a+2*b+c）
# c3（3，5，9）
#
#
# 6#6。可变位置参数
# #6。可变参数（位置），先固定参数，在可变参数
# def hello（msg，*names）：
#     print（'Hello，'，names，msg）
# hello（‘新年好’，’zhangsan'，'lisi'，‘wangwu'，‘zhaoliu'）
#
# 7#7。可变关键词参数
# #7.可变参数（关键词）
# def hello（msg，*#names）：
#     print（'老大是：’，names['B0SS']，msg）
#     print（'老二是：'，names['B0SS2']，msg）
# hello（'新年好’，BOSS='张三’，B0SS2='李四’，Guard='王五’）
#
# 8#8。进一步混搭
# #顺序必须是：必选参数、默认参数、可变位置参数、命名关键字参数和可变关键字
# def f（a，b，c，d，*args，e，f，**kwargs）：
#     print（a，b，c，d，e，f）
#     print（args）
#     print（kwargs）
# f（1，2，3，4，5，e=6，f=7，x=8）
#
#
#
# #9.强制位置参数
# def f（a，b，/，c，d，*，e，f，**kwargs）：
#     print（a，b，c，d，e，f）
# f（3，4，5，6，e=7，f=8，z=9，w=10）
#
#
#
# #10。函数调用-开包列表和元祖
# def hello（msg，*names）:
#     print（'Hello，'，*names，msg）
# names_param=['张三’，‘李四’，‘王五’]
# hello（'您好’，*names_param）
#
# 11#11.函数调用-开包字典
# def hello（msg，**names）：
#     print（'老大是：’，names['B0SS']，msg）
#     print（'老二是：’，names['B0SS2']，msg）
# data={'B0SS'：'张三’，‘B0SS2'：'李四’，‘Guard'：'王五'}
# hello（'新年好’，**data）

# %% [markdown]
# if return
# #返回值：
# #1。可以有返回值，也可以没有，None.
# #2。返回值通过return来返回
# #3.一旦遇到return，函数执行接结束了
# #4。如果返回多个值，多个值被包在一个元祖里

# %% [markdown]
# 内置函数
# https://docs.python.org/zh-cn/3/library/functions.html

# %% [markdown]
# 全局变量和局部变量 global vs local
# #1.局部变量：def和cLass定义的变量
# #2.全局变量：在脚本内（def和class外）定义的变量
# #3.局部变量只有在局部可用
# #4。全局变量可以在global和函数内访问
# #5。局部变量如果和全局变量重名，局部变量优先使用
# #6.全局是指在当前文件（模块）内全局周

# %% [markdown]
# vscode
# workspace：空间
# setting：设置
# plugin：插件
#
# 运行当前单元测试文件
# 在Python 终端中运行选定内容
#
# pip镜像
# Mac修改~/.pip/pip.conf（没有就创建一个），修改index-url至tuna，内容如下：
# [global]
# index-url=https://pypi.tuna.tsinghua.edu.cn/simple Windows直接在user目录中创建一个pip目录，如：C:\Users\maishu\pip，新建文件pip.ini，内容如下：
# [globa]
# index-url =https://pypi.tuna.tsinghua.edu.cn/simple
#
#
# 格式化文档
#
# 重命名符号
#
# try/except
# try/except/else
# try/except/else/finally
# try/except/finally
# try/finally
# try
#
# >代码
# 首选项：配置用户代码片段

# %% [markdown]
# 什么是虚拟环境
# 帮你管理多个Python的环境，确保你的项目A和其他项目不产生环境冲突
# 虚拟环境的选择
# virtualenv，pyenv，venv等命令
# python-m venv env

# %% [markdown]
# 算数运算符
# **幂 > *乘/除%取余//地板除 > +加-减

# %% [markdown]
# 赋值运算符
# 运算符主要有：=、+=、-=、*=、/=、//=、**=、%=
#
# =	最基本的赋值运算	x = y	x = y
# +=	加赋值	x += y	x = x + y
# -=	减赋值	x -= y	x = x - y
# *=	乘赋值	x *= y	x = x * y
# /=	除赋值	x /= y	x = x / y
# %=	取余数赋值	x %= y	x = x % y
# **=	幂赋值	x **= y	x = x ** y
# //=	取整数赋值	x //= y	x = x // y
# &=	按位与赋值	x &= y	x = x & y
# |=	按位或赋值	x |= y	x = x | y
# ^=	按位异或赋值	x ^= y	x = x ^ y
# <<=	左移赋值	x <<= y	x = x << y，这里的 y 指的是左移的位数
# >>=	右移赋值	x >>= y	x = x >> y，这里的 y 指的是右移的位数

# %% [markdown]
# 身份运算
# is
# is not
#
# 成员运算
# in
# not in
#
#
# //https://www.cnblogs.com/relax1949/p/7452017.html
# 位运算符
# python位运算符：python的位运算符是把数字看作二进制来进行计算的。
# 按位与（&）：如果两个二进位都为1，则该位结果为1，否则为0
# 按位或（|）：只要一个为1，则为1，否则为0
# 按位异或（^）：两个二进位相异为为1（即两个二进位要相反），否则为0
# 取反（~）：对数据的每个二进制位取反，即把1变0，把0变1
# 左移动：运算数的各二进位全部向左移若干位
# 右移动：运算数的各二进位全部向右移若干位

# %% [markdown]
# eval('dir()')
# dir() 函数不带参数时，返回当前范围内的变量、方法和定义的类型列表；带参数时，返回参数的属性、方法列表
# eval()用来执行一个字符串表达式，并返回表达式的值。可以把list,tuple,dict和string相互转化。
#
# ①数据类型
# ①数字：int，float，complex
# ②字符串：str
# ③Bool:True，False
# ④数据结构：list，tuple，set，dict
# ⑤其他类型：各种类
# ②数字的集中类型：十进制，二进制，十六进制，八进制
# ③类型的确定④类型的转换

# %% [markdown]
# python -m pip install pyinstaller

# %% [markdown]
# 彻底掌握Pythun容器类5大金刚，8种玩法

# %% [markdown]
# 列表 建-增删改查操一切复
#
# //列表建
# "list建立": {
#     "prefix": ["list","listjian"],
#     "body": "list(${1:可迭代对象列表,元祖，集合，字典，range})",
#     "description": "建立一个列表"
#   },
#
#     "list建立": {
#     "prefix": ["listkong","listjiankong"],
#     "body": "${1:列表名} = []\n$0",
#     "description": "建立一个空列表"
#   },
#
#   //列表增
#    "列表后增": {
#         "prefix": ["listzenghou","listapp"],
#         "body": [
#          "${1:列表名}.append('${2:字符串，元祖}')",
#         ],
#         "description": "列表后增"
#         },
#
#    "列表索引增": {
#         "prefix": ["listzenghou","listapp"],
#         "body": [
#          "${1:列表名}.insert(${2:索引，超出长度放最后},${3:增加元素})",
#         ],
#         "description": "列表索引增"
#         },
#
#    "列表开包增": {
#         "prefix": ["listzenghou","listapp"],
#         "body": [
#          "${1:列表名}.extend(${2:列表名开包元素后增})",
#         ],
#         "description": "列表索引增"
#         },
#
#         //列表删
#
#          "列表删del": {
#         "prefix": ["listdel","listshand"],
#         "body": [
#          "del ${1:列表名}[${2:切片索引}]",
#         ],
#         "description": "列表删del"
#         },
#
#          "列表删pop": {
#         "prefix": ["listshan","listpop"],
#         "body": [
#          "${1:列表名}.pop(${2:默认去掉最后一个,可指定索引})",
#         ],
#         "description": "列表删pop，会返回pop的值，如果下标越界，抛出IndexError"
#         },
#
#          "列表删remove": {
#         "prefix": ["listmove","listsmove"],
#         "body": [
#          "${1:列表名}.remove(${2:只会删除第一个符合条件的列表值})",
#         ],
#         "description": "列表删remove，只会删除第一个符合条件的，如果没有符合条件的，就抛出ValueError"
#         },
#
#         //列表改：修改元素的值
#          "列表改": {
#         "prefix": ["listgai","listqie"],
#         "body": [
#          "${1:列表名}[${2:索引}]=${3:修改值}",
#         ],
#         "description": "列表改"
#         },
#
#         //列表查：查询元素[]，index（），len（）
#
#      "列表查-按索引查值": {
#         "prefix": ["listchai","listchai"],
#         "body": [
#          "${1:列表名}[${2:索引}]",
#         ],
#         "description": "列表查-按索引查值，从0或-1开始，下标越界，会出现IndexError"
#         },
#
#      "列表查-按值查索引": {
#         "prefix": ["listchai","listchai"],
#         "body": [
#          "${1:列表名}.index(${2:值})",
#         ],
#         "description": "列表查-按值查索引，如果没有，会抛出ValueError "
#         },
#
#     "列表查-值是否存在列表": {
#         "prefix": ["listin","listnotin"],
#         "body": [
#          "${1:列表的值} ${2|in,not in |} ${3:列表名}  ",
#         ],
#         "description": "列表查-值是否存在列表 "
#         },
#
#
#         "列表查-列表的长度": {
#         "prefix": ["listlen","listchang"],
#         "body": [
#          "len(${1:列表名})",
#         ],
#         "description": "列表查-值是否存在列表 "
#         },
#
#         //列表操做：loop，+，*比较，sort，reverse，max，min，sum和
#          "列表loop循环": {
#         "prefix": ["listforin","listxunhuan"],
#         "body": [
#          "for n in ${1:列表名}",
#         ],
#         "description": "列表loop循环for-in "
#         },
#
#      "列表loop循环": {
#         "prefix": ["listforivin","listivxunhuan"],
#         "body": [
#          "for i,v in enumerate(${1:列表名})",
#         ],
#         "description": "列表loop循环for-iv-in "
#         },
#
#      "列表操-基本运算": {
#         "prefix": ["listforivin","listivxunhuan"],
#         "body": [
#          "${1:列表名} + ${2:列表名}",
#         ],
#         "description": "extend是一样的效果print（scores*3）"
#         },
#
#
#     "列表操-排序": {
#         "prefix": ["listpaixu","listisort"],
#         "body": [
#          "sorted(${1:列表名},reverse=True)",
#         ],
#         "description": "复制为另一张表，从大到小排序"
#         },
#
# 1ist.reverse（）会修改原列表
# reversed（List）不会修改原列表，会返回一个新的
# sort()会修改原列表
# 列表.sort(reverse=True)
# sorted可以指定key
# sorted(name_scores,key=lambda n:n[1]
#
#     "列表操-包元祖的列表排序": {
#         "prefix": ["listpaixu","listisort"],
#         "body": [
#          "sorted(${1:列表名},key=lambda n:n[1],reverse=True)",
#         ],
#         "description": "列表操-包元祖的列表排序，key指定匿名函数"
#         },
# max，min，sum
#
#     "列表操-最大最小和": {
#         "prefix": ["listmax","listmin"],
#         "body": [
#          "${1|max,min,sum|(${2:列表名})",
#         ],
#         "description": "列表操-最大最小和"
#         },
#
# //切片操作 start:end:step
#   "列表操-切片": {
#         "prefix": ["listgai","listqiepian"],
#         "body": [
#          "${1:列表名}[${2:切片操作 start:end:step}]",
#         ],
#         "description": "列表cao-切片"
#         },
#
#  //列表复：推导式，map，filter
#   "列表复制": {
#         "prefix": ["listgai","listqiepian"],
#         "body": [
#          "${1:新列表名}=${2:列表}[:]",
#         ],
#         "description": "列表复制"
#         },
#
#  //列表推导式
#
#     "列表推导式forin": {
#         "prefix": "lc",
#         "body": "[${1:value} for ${2:value} in ${3:iterable}]$0",
#         "description" : "基于现有列表创建新的列表的列表推导式."
#     },
#
#
#     "列表推导式if-else-for-in": {
#         "prefix": "lcie",
#         "body": "[${1:value} if ${2:condition} else ${3:condition} for ${4:value} in ${5:iterable}]$0",
#         "description" : "List comprehension for creating a list based on existing lists, with conditional if-else statement."
#     },
#
#
#     "列表推导式for-in-if过滤": {
#         "prefix": "lci",
#         "body": "[${1:value} for ${2:value} in ${3:iterable} if ${4:condition}$0]",
#         "description" : "List comprehension for creating a list based on existing lists, with conditional if statement."
#     },
#
# "map": {
#     "prefix": "map",
#     "body":
#     "map(${1:外部函数名或lambda函数}, ${2:一个或多个可迭代对象列表list(range(100)),元祖，集合，字典})",
#     "description": "根据提供的函数对指定序列做映射"
#   },
#
#
#       "Map": {
#         "prefix": "map",
#         "body": [
#             "$1 = ${2:collection_to_cast_to}(map(${3:function_to_apply}, ${4:list_of_inputs}))"
#         ],
#         "description": "Map"
#     },

# %% [markdown]
# //基本概念：tuple是一个有序的，不可改的数据结构immutable
# //#优点：1x快2.安全3.元组可以被作为dict的key
# //建-查操一切复,不能增删改
#
# //建
#
# “元祖tuple建”：{
#   “ prefix”：“ tuplejian”，
#   “身体”： [
#     “元组（$ {1：列表或字符串}）”
#   ]，
#   “ description”：“元祖tuple建,tuple(5等于(5,))”
# }
#
#
# #查
# “元祖tuple按索引查值”：{
#   “ prefix”：“ tuplecha”，
#   “身体”： [
#     “ $ {1：元祖名} [$ {2：元祖索引}]”
#   ]，
#   “ description”：“元祖tuple按索引查值”
# }
#
# #操
# #a.sort（）
# #a.reverse（）
# #切
# b=a[0：-1]
# print（b）
# #复
# c=a[:]

# %% [markdown]
# //字符串
# #基-是一个字符序列（sequence），基于utf-8编码
#
# 基本概念
# name=‘张三’
# print（name）
# for n in'hellomaishu'：
# print（n）
# print（dir（str））
#
# 建
# 单引号
# 双引号
# 三个单引号
# 三个双引号
# str(列表或元祖)
#
# 增
# 切片字符串，+加号拼接字符串
# #3.增：字符串是immutable
#  name='zhangsan'
# #name[-1]='m'
# #name2='zhangsan'+'m'
# name2=name[：-1]+'m'
# print（jomame））
# print（td（ndme））
#
# #3.3同一个字符串在内存中就只有一份
# #4.删-不可能的#5。改-不可能的
#
# 查
#
# #6，1可以通过下标来访问一个字符shame=‘打工是不可能的！’
# #print（shame[-1]）
# #6.2子串是否存在-membership:in，not in
# #identity:is，is not
# #print（type（shame）is not str）
# #print（‘可能x’ not in shame）
#
# #6.3开头，结尾
# print（shame.startswith（'X打工’））
# print（shame.endswith（'！'））
# #6.4下标
# print（shame.index（'可能‘））
#
# 操作
# #格式化输出
# name='zhangsan'
# greeting=‘hello，'+name+'，吃了吗？
# g2='hello，{name}，{name2}，吃了吗？’
# print（g2.format（name='麦叔’，name2='张三））print（f'hello，{name}，喝了吗？）
# #拆分
# names=‘张三，李四，王五，二麻子！
# for n in names.split（'，’）：print（n）
#
# names2=['张三’，‘莉莉丝’，’王五’]
# #print（"-".join（names2））
# #print（h.join（name））
#
# #查找：出现次数，re
# name=‘我是一个小小小小小小小鸟'
# print（name.count（'小‘））
#
# #改变大小写
# zhangsan =‘zhHongsan is a bad guy'
# print（zhangsan.title（））
# print（zhangsan.capitalize（））
# print（zhangsan.upper（））
# print（zhangsan.lower（））
# print（zhangsan.swapcase（））
#
# #运算
# name8='wangba'
# print（name8+name）
# print（name8*8）
#
# 去空格
# print(name8.strip())
# print(name8.lstrip())
# print(name8.rstrip())
#
# #查漏补缺-替换
# print（name.replace（‘小，‘大’））
#
# #比较：
# print（‘maishu'>‘Maishu3'）
# #1个个字符比过去，碰到能决定大小的，就直接返回
# #如果一边已经用完了，另一边还有，另一边就赢了
# #小写字母大于大写字母；其他顺序查ASCII

# %% [markdown]
# //集合 set/frozenset
#
# 基本概念
# #1.基础：不能重复，不分先后，只能加入immutable（不可变）的内容
# class Person：
#     def init（self，name）：
#         self.name=name
# p=Person（‘wangwu'）
# names={'zs'，‘lisi'，'zs'，p}
# print（names）
# p.name='wangwuwu'
# print（names）
#
#
# #2.创建：大括号，空的代表dict，用set可以空的，也可以转换iterable的对象
# score=set（）
# score={98，89，69，96}
# score=set（（4，5，6））#iterable
# print（score）
#
# #3.增
# score.add（'zs'）
# print（score）
#
#
# #4.删
# score.remove（'zs'）
# print（score）
# score.discard（'1s'）#有就移除，没有就什么也不错，但不会报错
# print（score）
# score.clear（））#清楚所有内容
# print（score）
#
# #5。改-没有顺序
# #6.查in not in成员运算符
# score={98，89，69，96}
# #print（98 not in score）
# #7.操作：set集合一并，交
# s1={1，2，3，4，5}
# s2={4，5，6，7，8}
# #合并
# s3=s1 |s2
# s3=s1.union（s2）
# #交
# s3=s1&s2  #s1.intersection（s2）
# #差
# s3=s1-s2
# #不重复的集合
# s3=s1~s2
# print（s3）
#
# #比较
# print（s1.issuperset（s2））#s1>s2
# print（s3）
#
# #8.切片
# #9.复制
# p2=Person（'lisi'）
# score.add（p2）
# print（score）
# s4=score.copy（）
# print（s4）
#
# #10.frozenset
# s5=frozenset（s4）
# print（s5）
# s5.add（88）

# %% [markdown]
# //字典
# #1，基础-键值对，key:value，key必须是immutable的对象s={'zs'：66，'lis'：88，'ms'：100}
# s={'zs'：{'dd'：88，'xx'：99}，'lis'：88，'ms'：100}
#
# #2，创建
# s={'zs'：66，‘1is'：88，'ms'：100}#set也用大括号，直接，是创建一个空的字典，
# s=dict（）#一个空的字典
# s=dict（[（1，99），（2，88），（3，100）]）#包含成对的数据的iterable
# print（s）
#
# names=['za'，'lis'，‘ww'，‘wb']
# scores=[78，56，78，99]
# s=dict（zip（names，scores））#zip是拉链的意思
# print（s）
#
# #3，增
# s['ruhua']=89
# print（s）
# s['damei']=77
# print（s）
#
# #4.删 del pop，popitem，clear
# del s['damei']#如果删除的key不存在，会抛出KeyError
#  print（s）
# print（s.pop（'ruhua'））
# print（s）
# print（s.popitem（））
# print（s）
# s.clear（）
# print（s）
#
# #5，改
# print（s）
# s['damei]=99
# print（s）
#
# #6，查[]，ged，in，not in
#  print（'ww' in s）
# print（s['ww']）
# print（s.get（'wwx'））
# print（s）
# s.setdefault（'www'，'google.com'）
# print（s['www）
#
# #7.操遍历，items，keys，values，sort
# for k in s：
# print（k，s[k]）
# print（List（s.keys（）））
# print（list（s.values（）））
# print（list（s.items（）））
# s2={k:v for k，v in sorted（s.items（））}
# print（s2）
#
# #8，切片fromkeys
# #9.复制copy s4=s.copy（）
# print（s4）
# s5={'dfd'：88，'xxx'：89，‘ww'：120}
# print（s）
# print（s5）
# s.update（s5）
# print（s）
#
# 排序
# >>>scores={2:98,1:87,3:65,4:95}
# >>>sorted(scores. keys())
# [1,2,3,4]
# >>>sorted(scores. keys(), reverse=True)
# [4,3,2,1]
# >>> sorted(scores. values(), reverse=True)
# [98,95,87,65]
# >>>scores. items()
# dict_items([(2,98),(1,87),(3,65),(4,95)])
# >>>sorted(scores. items())
# [(1,87),(2,98),(3,65),(4,95)]
# >>>sorted(scores. items(), key=lambda item: item[1])
# [(3,65),(1,87),(4,95),(2,98)]
# ss>sorted(scores. items(), key=lambda item: item[1], reverse=True)
# [(2,98),(4,95),(1,87),(3,65)]
# >>{k:v for k,v in sorted(scores. items(), key=lambda item: item[1], reverse=True)}
# {2:98,4:95,1:87,3:65}
# >>>I

# %% [markdown]
# 字符串切片
# #a[start:end:step]
# #|m|a|i|sIh|u
# #0123456
# #-6-5-4-3-2-1
# #以下同样适用于11st，字符串，元组
# #1，取单个元素alindex]
# #2，取子串，alstart:end]注意不包括end
# #3.start和end取负数#4，start>end怎么办
# #5，空的start或者end，
# #6，可以用None代替空的start
# #7.step
# #8.step为负：a[：：-1]

# %% [markdown]
# 判断一个对象是否一个可迭代对象
# from collections.abc import Iterable
# print(isinstance(name,Iterable))

# %% [markdown]
# 如何用一条语句合并两个字典
# x={'小明’：88，‘如花’：86}
# y={'大美’：99，如花’：87}
# #适用于python3.5及以上
# z={**x，**y，‘张三：100}
# print（z）
#
# x={'小明：88，‘如花’：86}
# y={'大美：99}
# #适用于python3.4及以下
# z=x.copy（）
# z.update（y）
# print（z）

# %% [markdown]
# 如何在Puthon中执行外部命令
# import subprocess#从3.5开始
# p=subprocess.run（['1s'，'-1']，capture_output=True）
# print（"=========="）
# print（p.stdout.decode（'UTF-8'））

# %% [markdown]
# 判断一个List是否为空的正确方法
# a=[3]
# if a：
#     print（"List is not empty"）
# else：
#     priht（"List is empty"）
# #1.数学0：·False，其他：True
# #2.[]：·False，·非空：True.·Dictionary，Tuple

# %% [markdown]
# for循环中如何访问元素的下标？
# scores=[100，99，95，90，89]
# for index，s in enumerate（scores，start=1）：
# #print（s）
# print（'第{}名：{}‘.format（index，s））

# %% [markdown]
# 实例方法，必须把se1f作为第一个参致，可以访问实例变量，只能通过实例名访问
# def bark（self）：
#     print（f’{self.name}叫了起来”）
#
# “类方法：定义时，必项把类作为第一个参球，可以访问类变量，可以通过实例名或类名访问
# @classmethod
# def dog_num（cts）：
#     num=0
#     forv in cls.dogbook.values（）：
#         num=num+v
#     return num
#
# 静态方法：不强制传入se1f或cls，他对类和实例都不能访间类变量，也不能访问实例变量；可以通过实例名或类名访问
# @staticmethod
# def total_weights（dogs）：
#     total=0
#     for o in dogs：
#         total=total+o.weight
#     return total

# %% [markdown]
# lambda函数
# 一句话写一个函数
# 只能有一句话的函数
# 可以匿名，也可以有名
# 语法糖衣：只是为了简单格式：lambdax:x+1
#
# def filter(scores, func):
# 	new_scores=[]
# 	for s in scores:
# 		if(func(s)):
# 			new_scores. append(s)
# 	return new_scores
# print(filter(scores, Lambda x:x%2==0))

# %% [markdown]
# ranking={'A':95,'B':99,'D':90,'C':87}
# print(sorted(ranking. items(), key=lambda itm: itm[1], reverse=True))

# %% [markdown]
# import tip13
# import tip13 as tt tip13.f1
# from tip13 import f1,f2
# from tip13 import *
#
# 库的地址
# >>>import sys
# >>>sys. builtin_module_names
# >sys.path

# %% [markdown]
# 私有变量
# class Human（）：
# 	def init（self，name）：
# 		self.name=name
# 	def get_name（self）：
# 		return self.name
# zs=Human（'张三）
# print（dir（zs））
# zs.__name=‘小张三’
# print（zs.name）
# print（zs._Human__name）
# print（zs.get_name（））

# %% [markdown]
# 类名：驼峰，如Dog，SheepDog，HelloWorld
# 方法名，变量名，参数，文件名：。全小写，多个单词下划线链接，如sheep_god，hellc_world。
# 如果是文件名，可以写成helloworld
# 私有属性：变量名前加一个下划线，如_secret，只是约定。
# Python解释器御用：方法名前加两个下划线，如__init__
